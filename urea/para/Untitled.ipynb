# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import string
solute = ['Na','K','Cl','HCO3','H2CO3','CO2','HPO4','H2PO4','urea','NH3','NH4','H','HCO2','H2CO2','glu']
compart = ['Lumen','Cell','ICA','ICB','LIS','Bath']
segment = ['pt','s3','sdl','mtal','ctal','dct','cnt','ccd','omcd','imcd']
new_segment = ['PT','SDL','TAL','DCT','CNT','CD']
gender = ['male','female']

# %%
file=open('male_PT_Na_para_flux.txt','r')
flux = 0
for i in file:
    line=i.split(' ')
    flux=flux+float(line[0])
flux
# Out:
# 42578.953777404626

# %%
gender = ['female']
for g in gender:
    for s in solute:
        transport_number = []
        for seg in segment:
            file = open(g+seg+'_flow_of_'+s+'_in_Lumen.txt','r')
            datalist = []
            for i in file:
                line = i.split(' ')
                datalist.append(float(line[0]))
            number_of_transport = datalist[0]-datalist[-1]
            transport_number.append(number_of_transport)
        segmental_transport = []
        segmental_transport.append(transport_number[0]+transport_number[1])
        segmental_transport.append(transport_number[2])
        segmental_transport.append(transport_number[3]+transport_number[4])
        segmental_transport.append(transport_number[5])
        segmental_transport.append(transport_number[6])
        segmental_transport.append(transport_number[7]+transport_number[8]+transport_number[9])
        fileoutput = open(g+'_'+s+'_transport_baseline.txt','w')
        for data in segmental_transport:
            fileoutput.write(str(data)+'\n')
        fileoutput.close()

# %%
def autolabel(rects, xpos='center'):
    """
    Attach a text label above each bar in *rects*, displaying its height.

    *xpos* indicates which side to place the text w.r.t. the center of
    the bar. It can be one of the following {'center', 'right', 'left'}.
    """

    xpos = xpos.lower()  # normalize the case of the parameter
    ha = {'center': 'center', 'right': 'left', 'left': 'right'}
    offset = {'center': 0.5, 'right': 0.3, 'left': 0.7}  # x_txt = x + w*off

    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()*offset[xpos], 1.01*height,
                '{}'.format(round(height,1)),fontsize=18, ha=ha[xpos], va='bottom')

# %%
def autolabel2(rects, xpos='center'):
    """
    Attach a text label above each bar in *rects*, displaying its height.

    *xpos* indicates which side to place the text w.r.t. the center of
    the bar. It can be one of the following {'center', 'right', 'left'}.
    """

    xpos = xpos.lower()  # normalize the case of the parameter
    ha = {'center': 'center', 'right': 'left', 'left': 'right'}
    offset = {'center': 0.5, 'right': 0.3, 'left': 0.7}  # x_txt = x + w*off

    for rect in rects:
        height = rect.get_height()
        ax2.text(rect.get_x() + rect.get_width()*offset[xpos], 1.01*height,
                '{}'.format(round(height,2)),fontsize=18, ha=ha[xpos], va='bottom')

# %%
bar_width=0.15
s='Na'
male_list = []
female_list = []
female = open('female_'+s+'_transport.txt','r')
male = open('male_'+s+'_transport.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
fig,ax = plt.subplots()
fig.set_figheight(4.5)
fig.set_figwidth(4.5)
Male=ax.bar(np.arange(2),male_list[-2:],bar_width,align='center',alpha=0.8,edgecolor='black',color='black',label='Male')
Female=ax.bar(np.arange(2)+bar_width,female_list[-2:],bar_width,align='center',alpha=0.8,edgecolor='black',color='white',label='Female')
ax.set_xticks(np.arange(2)+0.5*bar_width)
ax.set_xticklabels(new_segment[-2:],fontsize=20)
plt.yticks(fontsize=20)
#ax.set_xlabel('Segment',fontsize=20)
ax.set_ylabel('Total'+' '+s+' '+'transport (pmol/min)',fontsize=20)
#ax.legend(fontsize=40,markerscale=10)
#autolabel(Male,'left')
#autolabel(Female,'right')
plt.savefig(s+'_inset_transport')

# %%
bar_width = 0.15
s='K'
male_list = []
female_list = []
female = open('female_'+s+'_transport.txt','r')
male = open('male_'+s+'_transport.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
fig,ax = plt.subplots()
fig.set_figheight(2.5)
fig.set_figwidth(2.5)
Male=ax.bar(np.arange(2),[male_list[2],male_list[-2]],bar_width,align='center',alpha=0.8,color='skyblue',label='Male')
Female=ax.bar(np.arange(2)+bar_width,[female_list[2],female_list[-2]],bar_width,align='center',alpha=0.8,color='lightcoral',label='Female')
ax.set_xticks(np.arange(2)+0.5*bar_width)
ax.set_xticklabels([segment[2],segment[-2]],fontsize=20)
plt.yticks(fontsize=20)
#ax.set_xlabel('Segment',fontsize=20)
ax.set_ylabel('Total'+' '+s+' '+'transport (pmol/min)',fontsize=20)
#ax.legend(fontsize=40,markerscale=10)
#autolabel(Male,'left')
#autolabel(Female,'right')
plt.savefig(s+'_inset_transport')

# %%
s='Cl'
male_list = []
female_list = []
female = open('female_'+s+'_transport.txt','r')
male = open('male_'+s+'_transport.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
fig,ax = plt.subplots()
fig.set_figheight(4.5)
fig.set_figwidth(4.5)
Male=ax.bar(np.arange(2),male_list[-2:],bar_width,align='center',alpha=0.8,edgecolor='black',color='black',label='Male')
Female=ax.bar(np.arange(2)+bar_width,female_list[-2:],bar_width,align='center',alpha=0.8,edgecolor='black',color='white',label='Female')
ax.set_xticks(np.arange(2)+0.5*bar_width)
ax.set_xticklabels(new_segment[-2:],fontsize=20)
plt.yticks(fontsize=20)
#ax.set_xlabel('Segment',fontsize=20)
ax.set_ylabel('Total'+' '+s+' '+'transport (pmol/min)',fontsize=20)
#ax.legend(fontsize=40,markerscale=10)
#autolabel(Male,'left')
#autolabel(Female,'right')
plt.savefig(s+'_inset_transport')

# %%
bar_width = 0.15
s='urea'
male_list = []
female_list = []
female = open('female_'+s+'_transport.txt','r')
male = open('male_'+s+'_transport.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
fig,ax = plt.subplots()
fig.set_figheight(2.5)
fig.set_figwidth(2.5)
Male=ax.bar(np.arange(2),[male_list[2],male_list[3]],bar_width,align='center',alpha=0.8,color='skyblue',label='Male')
Female=ax.bar(np.arange(2)+bar_width,[female_list[2],female_list[3]],bar_width,align='center',alpha=0.8,color='lightcoral',label='Female')
ax.set_xticks(np.arange(2)+0.5*bar_width)
ax.set_xticklabels([new_segment[2],new_segment[3]],fontsize=20)
plt.yticks(fontsize=20)
ax.set_xlabel('Segment',fontsize=20)
ax.set_ylabel('Total'+' '+s+' '+'transport (pmol/min)',fontsize=20)
#ax.legend(fontsize=40,markerscale=10)
#autolabel(Male,'left')
#autolabel(Female,'right')
plt.savefig(s+'_inset_transport')

# %%
bar_width = 0.25
for s in solute:
    male_list = []
    female_list = []
    female = open('female_'+s+'_transport.txt','r')
    male = open('male_'+s+'_transport.txt','r')
    for i in male:
        line=i.split(' ')
        male_list.append(float(line[0]))
    for i in female:
        line=i.split(' ')
        female_list.append(float(line[0]))
    fig,ax = plt.subplots()
    fig.set_figheight(9)
    fig.set_figwidth(10)
    Male=ax.bar(np.arange(len(new_segment)),male_list,bar_width,align='center',alpha=0.8,edgecolor='black',color='black',label='Male')
    Female=ax.bar(np.arange(len(new_segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,edgecolor='black',color='white',label='Female')
    ax.set_xticks(np.arange(len(new_segment))+0.5*bar_width)
    ax.set_xticklabels(new_segment,fontsize=20)
    plt.yticks(fontsize=20)
    if s == 'Na':
        bar_width_ins = bar_width
        axins = inset_axes(ax,width=2,height=2,loc=7)
        Male_inset=axins.bar(np.arange(len(new_segment)),male_list,bar_width_ins,align='center',alpha=0.8,edgecolor='black',color='black',label='Male')
        Female_inset=axins.bar(np.arange(len(new_segment))+bar_width_ins,female_list,bar_width_ins,align='center',alpha=0.8,edgecolor='black',color='white',label='Female')
        axins.set_xticks(np.arange(len(new_segment))+0.5*bar_width_ins)
        axins.set_xticklabels(new_segment,fontsize=20)
        axins.set_xlim(4-1.5*bar_width_ins,5+2*bar_width)
        axins.set_ylim(0,100)
        plt.yticks(fontsize=20)
    if s == 'Cl':
        bar_width_ins = bar_width
        axins = inset_axes(ax,width=2,height=2,loc=7)
        Male_inset=axins.bar(np.arange(len(new_segment)),male_list,bar_width_ins,align='center',alpha=0.8,edgecolor='black',color='black',label='Male')
        Female_inset=axins.bar(np.arange(len(new_segment))+bar_width_ins,female_list,bar_width_ins,align='center',alpha=0.8,edgecolor='black',color='white',label='Female')
        axins.set_xticks(np.arange(len(new_segment))+0.5*bar_width_ins)
        axins.set_xticklabels(new_segment,fontsize=20)
        axins.set_xlim(5-1.5*bar_width_ins,6+2*bar_width)
        axins.set_ylim(0,50)
        plt.yticks(fontsize=20)
    #ax.set_xlabel('Segment',fontsize=20)
    if s == 'Na':
        sol = 'Na$^+$'
    elif s == 'K':
        sol = 'K$^+$'
    elif s == 'Cl':
        sol = 'Cl$^-$'
    elif s == 'HCO3':
        sol = 'HCO$_3^-$'
    elif s == 'H2CO3':
        sol = 'H$_2$CO$_3$'
    elif s == 'CO2':
        sol = 'CO$_2$'
    elif s == 'HPO4':
        sol = 'HPO$_4^{2-}$'
    elif s == 'H2PO4':
        sol = 'H$_2$PO$_4^-$'
    elif s == 'urea':
        sol = 'urea'
    elif s == 'NH3':
        sol = 'NH$_3$'
    elif s == 'NH4':
        sol = 'NH$_4^+$'
    elif s == 'H':
        sol = 'H$^+$'
    elif s == 'HCO2':
        sol = 'HCO$_2^-$'
    elif s == 'H2CO2':
        sol = 'H$_2$CO$_2$'
    else:
        sol = s
    ax.set_ylabel('Total'+' '+sol+' '+'transport (pmol/min)',fontsize=20)
    ax.legend(fontsize=20,markerscale=20)
    #autolabel(Male,'left')
    #autolabel(Female,'right')
    plt.savefig(s+'_transport',bbox_inches='tight')
    #plt.show()

# %%
new_segment = ['PT','SDL','TAL','DCT','CNT','CD']
bar_width = 0.25
fig,axarr = plt.subplots(3,3)
fig.set_figheight(40)
fig.set_figwidth(40)
s='Na'
male_list = []
female_list = []
female = open('female_'+s+'_transport.txt','r')
male = open('male_'+s+'_transport.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
axarr[0,0].bar(np.arange(len(new_segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
axarr[0,0].bar(np.arange(len(new_segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axarr[0,0].set_xticks(np.arange(len(new_segment))+0.5*bar_width)
axarr[0,0].set_xticklabels(new_segment,fontsize=30)
axarr[0,0].tick_params(axis='both',labelsize=30)
bar_width_ins = bar_width
axins = inset_axes(axarr[0,0],width=3,height=3,loc=7)
Male_inset=axins.bar(np.arange(len(new_segment)),male_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female_inset=axins.bar(np.arange(len(new_segment))+bar_width_ins,female_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axins.set_xticks(np.arange(len(new_segment))+0.5*bar_width_ins)
axins.set_xticklabels(new_segment,fontsize=30)
axins.set_xlim(4-1.5*bar_width_ins,5+2*bar_width)
axins.set_ylim(0,100)
axins.tick_params(axis='both',labelsize=30)
axarr[0,0].set_ylabel('Na$^+$ transport (pmol/min)',fontsize=35)
axarr[0,0].legend(fontsize=30,markerscale=30)

s='K'
male_list = []
female_list = []
female = open('female_'+s+'_transport.txt','r')
male = open('male_'+s+'_transport.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
axarr[0,1].bar(np.arange(len(new_segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
axarr[0,1].bar(np.arange(len(new_segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axarr[0,1].set_xticks(np.arange(len(new_segment))+0.5*bar_width)
axarr[0,1].set_xticklabels(new_segment,fontsize=30)
axarr[0,1].tick_params(axis='both',labelsize=30)
axarr[0,1].set_ylabel('K$^+$ transport (pmol/min)',fontsize=35)
axarr[0,1].legend(fontsize=30,markerscale=30)
#plt.yticks(fontsize=20)

s='Cl'
male_list = []
female_list = []
female = open('female_'+s+'_transport.txt','r')
male = open('male_'+s+'_transport.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
axarr[0,2].bar(np.arange(len(new_segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
axarr[0,2].bar(np.arange(len(new_segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axarr[0,2].set_xticks(np.arange(len(new_segment))+0.5*bar_width)
axarr[0,2].set_xticklabels(new_segment,fontsize=30)
axarr[0,2].tick_params(axis='both',labelsize=30)
bar_width_ins = bar_width
axins = inset_axes(axarr[0,2],width=3,height=3,loc=7)
Male_inset=axins.bar(np.arange(len(new_segment)),male_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female_inset=axins.bar(np.arange(len(new_segment))+bar_width_ins,female_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axins.set_xticks(np.arange(len(new_segment))+0.5*bar_width_ins)
axins.set_xticklabels(new_segment,fontsize=30)
axins.set_xlim(4-1.5*bar_width_ins,5+2*bar_width)
axins.set_ylim(0,50)
axins.tick_params(axis='both',labelsize=30)
axarr[0,2].set_ylabel('Cl$^-$ transport (pmol/min)',fontsize=35)
axarr[0,2].legend(fontsize=30,markerscale=30)

s='HCO3'
male_list = []
female_list = []
female = open('female_'+s+'_transport.txt','r')
male = open('male_'+s+'_transport.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
axarr[1,0].bar(np.arange(len(new_segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
axarr[1,0].bar(np.arange(len(new_segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axarr[1,0].set_xticks(np.arange(len(new_segment))+0.5*bar_width)
axarr[1,0].set_xticklabels(new_segment,fontsize=30)
axarr[1,0].tick_params(axis='both',labelsize=30)
bar_width_ins = bar_width
axins = inset_axes(axarr[1,0],width=3,height=3,loc=7)
Male_inset=axins.bar(np.arange(len(new_segment)),male_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female_inset=axins.bar(np.arange(len(new_segment))+bar_width_ins,female_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axins.set_xticks(np.arange(len(new_segment))+0.5*bar_width_ins)
axins.set_xticklabels(new_segment,fontsize=30)
axins.set_xlim(3-1.5*bar_width_ins,5+2*bar_width)
axins.set_ylim(0,10)
axins.tick_params(axis='both',labelsize=30)
axarr[1,0].set_ylabel('HCO$_3^-$ transport (pmol/min)',fontsize=35)
axarr[1,0].legend(fontsize=30,markerscale=30)

s='NH4'
male_list = []
female_list = []
female = open('female_'+s+'_transport.txt','r')
male = open('male_'+s+'_transport.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
axarr[1,1].bar(np.arange(len(new_segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
axarr[1,1].bar(np.arange(len(new_segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axarr[1,1].set_xticks(np.arange(len(new_segment))+0.5*bar_width)
axarr[1,1].set_xticklabels(new_segment,fontsize=30)
axarr[1,1].tick_params(axis='both',labelsize=30)
axarr[1,1].set_ylabel('NH$_4^+$ transport (pmol/min)',fontsize=35)
axarr[1,1].legend(fontsize=30,markerscale=30)

s='urea'
male_list = []
female_list = []
female = open('female_'+s+'_transport.txt','r')
male = open('male_'+s+'_transport.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
axarr[1,2].bar(np.arange(len(new_segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
axarr[1,2].bar(np.arange(len(new_segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axarr[1,2].set_xticks(np.arange(len(new_segment))+0.5*bar_width)
axarr[1,2].set_xticklabels(new_segment,fontsize=30)
axarr[1,2].tick_params(axis='both',labelsize=30)
axarr[1,2].set_ylabel('Urea transport (pmol/min)',fontsize=35)
axarr[1,2].legend(fontsize=30,markerscale=30)

male_list = []
female_list = []
female = open('female_TA_transport.txt','r')
male = open('male_TA_transport.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
Male=axarr[2,0].bar(np.arange(len(new_segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female=axarr[2,0].bar(np.arange(len(new_segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axarr[2,0].set_xticks(np.arange(len(new_segment))+0.5*bar_width)
axarr[2,0].set_xticklabels(new_segment,fontsize=30)
axarr[2,0].tick_params(axis='both',labelsize=30)
axarr[2,0].set_ylabel('TA transport (pmol/min)',fontsize=35)
axarr[2,0].legend(fontsize=30,markerscale=30)

male_list = []
female_list = []
female = open('female_water_reabsorption.txt','r')
male = open('male_water_reabsorption.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
Male=axarr[2,1].bar(np.arange(len(new_segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female=axarr[2,1].bar(np.arange(len(new_segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axarr[2,1].set_xticks(np.arange(len(new_segment))+0.5*bar_width)
axarr[2,1].set_xticklabels(new_segment,fontsize=30)
axarr[2,1].tick_params(axis='both',labelsize=30)
axarr[2,1].set_ylabel('Volume transport (nl/min)',fontsize=35)
axarr[2,1].legend(fontsize=30,markerscale=30)

fig.delaxes(axarr[2,2])
axarr[0,0].text(-1,axarr[0,0].get_ylim()[1],'A',size=40,weight='bold')
axarr[0,1].text(-1,axarr[0,1].get_ylim()[1],'B',size=40,weight='bold')
axarr[0,2].text(-1,axarr[0,2].get_ylim()[1],'C',size=40,weight='bold')
axarr[1,0].text(-1,axarr[1,0].get_ylim()[1],'D',size=40,weight='bold')
axarr[1,1].text(-1,axarr[1,1].get_ylim()[1],'E',size=40,weight='bold')
axarr[1,2].text(-1,axarr[1,2].get_ylim()[1],'F',size=40,weight='bold')
axarr[2,0].text(-1,axarr[2,0].get_ylim()[1],'G',size=40,weight='bold')
axarr[2,1].text(-1,axarr[2,1].get_ylim()[1],'H',size=40,weight='bold')

plt.savefig('Transport',bbox_inches='tight')
#plt.show()

# %%
segment = ['PT','SDL','mTAL','DCT','CNT','CCD','IMCD']
gender = ['female']
for g in gender:
    for s in solute:
        delivery_number = []
        for seg in segment:
            file = open(g+seg+'_flow_of_'+s+'_in_Lumen.txt','r')
            datalist = []
            for i in file:
                line = i.split(' ')
                datalist.append(float(line[0]))
            if seg == 'IMCD':
                number_of_delivery = datalist[-1]
            else:
                number_of_delivery = datalist[0]
            delivery_number.append(number_of_delivery)
        fileoutput = open(g+'_'+s+'_delivery_baseline.txt','w')
        for data in delivery_number:
            fileoutput.write(str(data)+'\n')
        fileoutput.close()

# %%
segment = ['PT','SDL','mTAL','DCT','CNT','CCD','urine']
bar_width = 0.25
for s in solute:
    male_list = []
    female_list = []
    female = open('female_'+s+'_delivery.txt','r')
    male = open('male_'+s+'_delivery.txt','r')
    for i in male:
        line=i.split(' ')
        male_list.append(float(line[0]))
    for i in female:
        line=i.split(' ')
        female_list.append(float(line[0]))
    fig,ax = plt.subplots()
    fig.set_figheight(9)
    fig.set_figwidth(10)
    Male=ax.bar(np.arange(len(segment)),male_list,bar_width,align='center',alpha=0.8,edgecolor='black',color='black',label='Male')
    Female=ax.bar(np.arange(len(segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,edgecolor='black',color='white',label='Female')
    ax.set_xticks(np.arange(len(segment))+0.5*bar_width)
    ax.set_xticklabels(segment,fontsize=20)
    plt.yticks(fontsize=20)
    bar_width_ins = bar_width
    axins = inset_axes(ax,width=2,height=2,loc=7)
    Male_inset=axins.bar(np.arange(len(segment)),male_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
    Female_inset=axins.bar(np.arange(len(segment))+bar_width_ins,female_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
    axins.set_xticks(np.arange(len(segment))+0.5*bar_width_ins)
    axins.set_xticklabels(segment,fontsize=20)
    axins.set_xlim(5-1.5*bar_width_ins,6+2*bar_width)
    axins.set_ylim(0,100)
    axins.tick_params(axis='both',labelsize=20)
    #ax.set_xlabel('Segment',fontsize=20)
    if s == 'Na':
        sol = 'Na$^+$'
    elif s == 'K':
        sol = 'K$^+$'
    elif s == 'Cl':
        sol = 'Cl$^-$'
    elif s == 'HCO3':
        sol = 'HCO$_3^-$'
    elif s == 'H2CO3':
        sol = 'H$_2$CO$_3$'
    elif s == 'CO2':
        sol = 'CO$_2$'
    elif s == 'HPO4':
        sol = 'HPO$_4^{2-}$'
    elif s == 'H2PO4':
        sol = 'H$_2$PO$_4^-$'
    elif s == 'urea':
        sol = 'urea'
    elif s == 'NH3':
        sol = 'NH$_3$'
    elif s == 'NH4':
        sol = 'NH$_4^+$'
    elif s == 'H':
        sol = 'H$^+$'
    elif s == 'HCO2':
        sol = 'HCO$_2^-$'
    elif s == 'H2CO2':
        sol = 'H$_2$CO$_2$'
    else:
        sol = s
    ax.set_ylabel(sol+' '+'delivery (pmol/min)',fontsize=20)
    ax.legend(fontsize=20,markerscale=20)
    #autolabel(Male,'left')
    #autolabel(Female,'right')
    plt.savefig(s+'_delivery',bbox_inches='tight')
    #plt.show()

# %%
segment = ['PT','SDL','mTAL','DCT','CNT','CCD','urine']
bar_width = 0.25
fig,axarr = plt.subplots(3,3)
fig.set_figheight(40)
fig.set_figwidth(40)
s='Na'
male_list = []
female_list = []
female = open('female_'+s+'_delivery.txt','r')
male = open('male_'+s+'_delivery.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
Male=axarr[0,0].bar(np.arange(len(segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female=axarr[0,0].bar(np.arange(len(segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axarr[0,0].set_xticks(np.arange(len(segment))+0.5*bar_width)
axarr[0,0].set_xticklabels(segment,fontsize=30)
axarr[0,0].tick_params(axis='both',labelsize=30)
bar_width_ins = bar_width
axins = inset_axes(axarr[0,0],width=2.5,height=2.5,loc=7)
Male_inset=axins.bar(np.arange(len(segment)),male_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female_inset=axins.bar(np.arange(len(segment))+bar_width_ins,female_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axins.set_xticks(np.arange(len(segment))+0.5*bar_width_ins)
axins.set_xticklabels(segment,fontsize=30)
axins.set_xlim(5-1.5*bar_width_ins,6+2*bar_width)
axins.set_ylim(0,100)
axins.tick_params(axis='both',labelsize=30)
axarr[0,0].set_ylabel('Na$^+$ delivery (pmol/min)',fontsize=35)
axarr[0,0].legend(fontsize=30,markerscale=30)

s='K'
male_list = []
female_list = []
female = open('female_'+s+'_delivery.txt','r')
male = open('male_'+s+'_delivery.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
Male=axarr[0,1].bar(np.arange(len(segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female=axarr[0,1].bar(np.arange(len(segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axarr[0,1].set_xticks(np.arange(len(segment))+0.5*bar_width)
axarr[0,1].set_xticklabels(segment,fontsize=30)
axarr[0,1].tick_params(axis='both',labelsize=30)
#ax.set_xlabel('Segment',fontsize=20)
axarr[0,1].set_ylabel('K$^+$ delivery (pmol/min)',fontsize=35)
axarr[0,1].legend(fontsize=30,markerscale=30)

s='Cl'
male_list = []
female_list = []
female = open('female_'+s+'_delivery.txt','r')
male = open('male_'+s+'_delivery.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
Male=axarr[0,2].bar(np.arange(len(segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female=axarr[0,2].bar(np.arange(len(segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axarr[0,2].set_xticks(np.arange(len(segment))+0.5*bar_width)
axarr[0,2].set_xticklabels(segment,fontsize=30)
axarr[0,2].tick_params(axis='both',labelsize=30)
bar_width_ins = bar_width
axins = inset_axes(axarr[0,2],width=2.5,height=2.5,loc=7)
Male_inset=axins.bar(np.arange(len(segment)),male_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female_inset=axins.bar(np.arange(len(segment))+bar_width_ins,female_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axins.set_xticks(np.arange(len(segment))+0.5*bar_width_ins)
axins.set_xticklabels(segment,fontsize=30)
axins.set_xlim(5-1.5*bar_width_ins,6+2*bar_width)
axins.set_ylim(0,100)
axins.tick_params(axis='both',labelsize=30)
axarr[0,2].set_ylabel('Cl$^-$ delivery (pmol/min)',fontsize=35)
axarr[0,2].legend(fontsize=30,markerscale=30)

s='HCO3'
male_list = []
female_list = []
female = open('female_'+s+'_delivery.txt','r')
male = open('male_'+s+'_delivery.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
Male=axarr[1,0].bar(np.arange(len(segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female=axarr[1,0].bar(np.arange(len(segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axarr[1,0].set_xticks(np.arange(len(segment))+0.5*bar_width)
axarr[1,0].set_xticklabels(segment,fontsize=30)
axarr[1,0].tick_params(axis='both',labelsize=30)
bar_width_ins = bar_width
axins = inset_axes(axarr[1,0],width=5,height=5,loc=7)
Male_inset=axins.bar(np.arange(len(segment)),male_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female_inset=axins.bar(np.arange(len(segment))+bar_width_ins,female_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axins.set_xticks(np.arange(len(segment))+0.5*bar_width_ins)
axins.set_xticklabels(segment,fontsize=30)
axins.set_xlim(3-1.5*bar_width_ins,6+2*bar_width)
axins.set_ylim(0,20)
axins.tick_params(axis='both',labelsize=30)
axarr[1,0].set_ylabel('HCO$_3^-$ delivery (pmol/min)',fontsize=35)
axarr[1,0].legend(fontsize=30,markerscale=30)

s='NH4'
male_list = []
female_list = []
female = open('female_'+s+'_delivery.txt','r')
male = open('male_'+s+'_delivery.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
Male=axarr[1,1].bar(np.arange(len(segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female=axarr[1,1].bar(np.arange(len(segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axarr[1,1].set_xticks(np.arange(len(segment))+0.5*bar_width)
axarr[1,1].set_xticklabels(segment,fontsize=30)
axarr[1,1].tick_params(axis='both',labelsize=30)
axarr[1,1].set_ylabel('NH$_4^+$ delivery (pmol/min)',fontsize=35)
axarr[1,1].legend(fontsize=30,markerscale=30)

s='urea'
male_list = []
female_list = []
female = open('female_'+s+'_delivery.txt','r')
male = open('male_'+s+'_delivery.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
Male=axarr[1,2].bar(np.arange(len(segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female=axarr[1,2].bar(np.arange(len(segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axarr[1,2].set_xticks(np.arange(len(segment))+0.5*bar_width)
axarr[1,2].set_xticklabels(segment,fontsize=30)
axarr[1,2].tick_params(axis='both',labelsize=30)
axarr[1,2].set_ylabel('Urea delivery (pmol/min)',fontsize=35)
axarr[1,2].legend(fontsize=30,markerscale=30)

s='TA'
male_list = []
female_list = []
female = open('female_'+s+'_delivery.txt','r')
male = open('male_'+s+'_delivery.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
Male=axarr[2,0].bar(np.arange(len(segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female=axarr[2,0].bar(np.arange(len(segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axarr[2,0].set_xticks(np.arange(len(segment))+0.5*bar_width)
axarr[2,0].set_xticklabels(segment,fontsize=30)
axarr[2,0].tick_params(axis='both',labelsize=30)
axarr[2,0].set_ylabel('TA delivery (pmol/min)',fontsize=35)
axarr[2,0].legend(fontsize=30,markerscale=30)

s='volume'
male_list = []
female_list = []
female = open('female_'+s+'_delivery.txt','r')
male = open('male_'+s+'_delivery.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
Male=axarr[2,1].bar(np.arange(len(segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female=axarr[2,1].bar(np.arange(len(segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axarr[2,1].set_xticks(np.arange(len(segment))+0.5*bar_width)
axarr[2,1].set_xticklabels(segment,fontsize=30)
axarr[2,1].tick_params(axis='both',labelsize=30)
bar_width_ins = bar_width
axins = inset_axes(axarr[2,1],width=2.5,height=2.5,loc=7)
Male_inset=axins.bar(np.arange(len(segment)),male_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female_inset=axins.bar(np.arange(len(segment))+bar_width_ins,female_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axins.set_xticks(np.arange(len(segment))+0.5*bar_width_ins)
axins.set_xticklabels(segment,fontsize=30)
axins.set_xlim(5-1.5*bar_width_ins,6+2*bar_width)
axins.set_ylim(0,2)
axins.tick_params(axis='both',labelsize=30)
axarr[2,1].set_ylabel('Volume delivery (nl/min)',fontsize=35)
axarr[2,1].legend(fontsize=30,markerscale=30)

fig.delaxes(axarr[2,2])
axarr[0,0].text(-1,axarr[0,0].get_ylim()[1],'A',size=40,weight='bold')
axarr[0,1].text(-1,axarr[0,1].get_ylim()[1],'B',size=40,weight='bold')
axarr[0,2].text(-1,axarr[0,2].get_ylim()[1],'C',size=40,weight='bold')
axarr[1,0].text(-1,axarr[1,0].get_ylim()[1],'D',size=40,weight='bold')
axarr[1,1].text(-1,axarr[1,1].get_ylim()[1],'E',size=40,weight='bold')
axarr[1,2].text(-1,axarr[1,2].get_ylim()[1],'F',size=40,weight='bold')
axarr[2,0].text(-1,axarr[2,0].get_ylim()[1],'G',size=40,weight='bold')
axarr[2,1].text(-1,axarr[2,1].get_ylim()[1],'H',size=40,weight='bold')
#plt.show()
plt.savefig('delivery',bbox_inches='tight')

# %%
bar_width = 0.15
s='Na'
male_list = []
female_list = []
female = open('female_'+s+'_delivery.txt','r')
male = open('male_'+s+'_delivery.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
fig,ax = plt.subplots()
fig.set_figheight(4.5)
fig.set_figwidth(4.5)
Male=ax.bar(np.arange(3),male_list[-3:],bar_width,align='center',alpha=0.8,edgecolor='black',color='black',label='Male')
Female=ax.bar(np.arange(3)+bar_width,female_list[-3:],bar_width,align='center',alpha=0.8,edgecolor='black',color='white',label='Female')
ax.set_xticks(np.arange(3)+0.5*bar_width)
ax.set_xticklabels(segment[-3:],fontsize=20)
plt.yticks(fontsize=20)
#ax.set_xlabel('Segment',fontsize=20)
ax.set_ylabel(s+' '+'delivery (pmol/min)',fontsize=20)
#ax.legend(fontsize=40,markerscale=10)
#autolabel(Male,'left')
#autolabel(Female,'right')
plt.savefig(s+'_inset_delivery')

# %%
s='Cl'
male_list = []
female_list = []
female = open('female_'+s+'_delivery.txt','r')
male = open('male_'+s+'_delivery.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
fig,ax = plt.subplots()
fig.set_figheight(4.5)
fig.set_figwidth(4.5)
Male=ax.bar(np.arange(3),male_list[-3:],bar_width,align='center',alpha=0.8,edgecolor='black',color='black',label='Male')
Female=ax.bar(np.arange(3)+bar_width,female_list[-3:],bar_width,align='center',alpha=0.8,edgecolor='black',color='white',label='Female')
ax.set_xticks(np.arange(3)+0.5*bar_width)
ax.set_xticklabels(segment[-3:],fontsize=20)
plt.yticks(fontsize=20)
#ax.set_xlabel('Segment',fontsize=20)
ax.set_ylabel(s+' '+'delivery (pmol/min)',fontsize=20)
#ax.legend(fontsize=40,markerscale=10)
#autolabel(Male,'left')
#autolabel(Female,'right')
plt.savefig(s+'_inset_delivery')

# %%
segment = ['pt','s3','sdl','mtal','ctal','dct','cnt','ccd','omcd','imcd']
new_segment = ['PT','SDL','TAL','DCT','CNT','CD']
gender = ['female']
for g in gender:
    transport_number = []
    for seg in segment:
        file = open(g+seg+'_water_volume_in_Lumen.txt','r')
        datalist = []
        for i in file:
            line = i.split(' ')
            datalist.append(float(line[0]))
        number_of_transport = datalist[0]-datalist[-1]
        transport_number.append(number_of_transport)
    water_transport=[]
    water_transport.append(transport_number[0]+transport_number[1])
    water_transport.append(transport_number[2])
    water_transport.append(transport_number[3]+transport_number[4])
    water_transport.append(transport_number[5])
    water_transport.append(transport_number[6])
    water_transport.append(transport_number[7]+transport_number[8]+transport_number[9])
    fileoutput = open(g+'_water_reabsorption_baseline.txt','w')
    for data in water_transport:
        fileoutput.write(str(data)+'\n')
    fileoutput.close()

# %%
segment = ['PT','SDL','mTAL','DCT','CNT','CCD','IMCD']
gender = ['female']
for g in gender:
    delivery_number = []
    for seg in segment:
        file = open(g+seg+'_water_volume_in_Lumen.txt','r')
        datalist = []
        for i in file:
            line = i.split(' ')
            datalist.append(float(line[0]))
        if seg =='IMCD':
            number_of_delivery = datalist[-1]
        else:
            number_of_delivery = datalist[0]
        delivery_number.append(number_of_delivery)
    fileoutput = open(g+'_volume_delivery_baseline.txt','w')
    for data in delivery_number:
        fileoutput.write(str(data)+'\n')
    fileoutput.close()

# %%
male_list = []
female_list = []
female = open('female_water_reabsorption.txt','r')
male = open('male_water_reabsorption.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
fig,ax = plt.subplots()
fig.set_figheight(5.5)
fig.set_figwidth(5.5)
male_ins_list=male_list[3:]
male_ins_list.remove(male_ins_list[3])
female_ins_list=female_list[3:]
female_ins_list.remove(female_ins_list[3])
Male=ax.bar(np.arange(6),male_ins_list,bar_width,align='center',alpha=0.8,edgecolor='black',color='black',label='Male')
Female=ax.bar(np.arange(6)+bar_width,female_ins_list,bar_width,align='center',alpha=0.8,edgecolor='black',color='white',label='Female')
ax.set_xticks(np.arange(6)+0.5*bar_width)
segment_ins=segment[3:]
segment_ins.remove(segment_ins[3])
ax.set_xticklabels(segment_ins,fontsize=20)
plt.yticks(fontsize=20)
#ax.set_xlabel('Segment',fontsize=20)
ax.set_ylabel('Water reabsorption (nl/min)',fontsize=20)
#ax.legend(fontsize=40,markerscale=10)
#autolabel(Male,'left')
#autolabel(Female,'right')
plt.savefig('water_inset_reabsorption')

# %%
bar_width = 0.25
male_list = []
female_list = []
female = open('female_water_reabsorption.txt','r')
male = open('male_water_reabsorption.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
fig,ax = plt.subplots()
fig.set_figheight(9)
fig.set_figwidth(10)
Male=ax.bar(np.arange(len(new_segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female=ax.bar(np.arange(len(new_segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
ax.set_xticks(np.arange(len(new_segment))+0.5*bar_width)
ax.set_xticklabels(new_segment,fontsize=20)
plt.yticks(fontsize=20)
#ax.set_xlabel('Segment',fontsize=20)
ax.set_ylabel('Water reabsorption (nl/min)',fontsize=20)
ax.legend(fontsize=20,markerscale=20)
#autolabel(Male,'left')
#autolabel(Female,'right')
plt.savefig('water_reabsorption',bbox_inches='tight')

# %%
segment = ['PT','SDL','mTAL','DCT','CNT','CCD','urine']
bar_width = 0.25
male_list = []
female_list = []
female = open('female_volume_delivery.txt','r')
male = open('male_volume_delivery.txt','r')
for i in male:
    line=i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line=i.split(' ')
    female_list.append(float(line[0]))
fig,ax = plt.subplots()
fig.set_figheight(9)
fig.set_figwidth(10)
Male=ax.bar(np.arange(len(segment)),male_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female=ax.bar(np.arange(len(segment))+bar_width,female_list,bar_width,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
ax.set_xticks(np.arange(len(segment))+0.5*bar_width)
ax.set_xticklabels(segment,fontsize=20)
plt.yticks(fontsize=20)
#ax.set_xlabel('Segment',fontsize=20)
ax.set_ylabel('Volume delivery (nl/min)',fontsize=20)
ax.legend(fontsize=20,markerscale=20)
bar_width_ins = bar_width
axins = inset_axes(ax,width=2,height=2,loc=7)
Male_inset=axins.bar(np.arange(len(segment)),male_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='black',label='Male')
Female_inset=axins.bar(np.arange(len(segment))+bar_width_ins,female_list,bar_width_ins,align='center',alpha=0.8,linewidth=2,edgecolor='black',color='white',label='Female')
axins.set_xticks(np.arange(len(segment))+0.5*bar_width_ins)
axins.set_xticklabels(segment,fontsize=20)
axins.set_xlim(5-1.5*bar_width_ins,6+2*bar_width)
axins.set_ylim(0,2)
axins.tick_params(axis='both',labelsize=20)
#autolabel(Male,'left')
#autolabel(Female,'right')
plt.savefig('volume_delivery',bbox_inches='tight')

# %%
bar_width = 0.2
male_urine = [0.2566]
female_urine = [0.2561]
male_sod_pot = [38.4949,23.2876]
female_sod_pot = [37.49,23.17]
fig,ax = plt.subplots()
fig.set_figheight(15)
fig.set_figwidth(20)
Male=ax.bar([0],male_urine,bar_width,align='center',alpha=0.8,color='skyblue',label='Male')
Female=ax.bar([bar_width],female_urine,bar_width,align='center',alpha=0.8,color='lightcoral',label='Female')
ax.set_xticks([0.5*bar_width,0.5*bar_width+1,0.5*bar_width+2])
ax.set_xticklabels(['Urine excretion','Na$^+$ excretion','K$^+$ excretion'],fontsize=34)
#ax.set_xlabel('Segment',fontsize=20)
ax.set_ylabel('nl/min',fontsize=34)
plt.yticks(fontsize=34)
ax.legend(fontsize=40,markerscale=10)
#autolabel(Male,'left')
#autolabel(Female,'right')
ax2 = ax.twinx()
Male_sod_pot = ax2.bar([1,2],male_sod_pot,bar_width,align='center',alpha=0.8,color='skyblue',label='Male')
Female_sod_pot = ax2.bar([1+bar_width,2+bar_width],female_sod_pot,bar_width,align='center',alpha=0.8,color='lightcoral',label='Female')
ax2.set_ylabel('pmol/min',fontsize=34)
plt.yticks(fontsize=34)
#autolabel2(Male_sod_pot,'left')
#autolabel2(Female_sod_pot,'right')
plt.savefig('Urine_and_sod_pot')

# %%
pos_pt=[1.1*i/199 for i in range(1,176)]
pos_s3=[1.1*i/199 for i in range(176,200)]
pos_sdl=[1.1+0.14*i/199 for i in range(1,200)]
pos_mtal=[1.1+0.14+0.2*i/199 for i in range(1,200)]
pos_ctal=[1.1+0.14+0.2+0.2*i/199 for i in range(1,200)]
pos_dct=[1.1+0.14+0.2+0.2+0.1*i/199 for i in range(1,200)]
pos_cnt=[1.1+0.14+0.2+0.2+0.1+0.2*i/199 for i in range(1,200)]
pos_ccd=[1.1+0.14+0.2+0.2+0.1+0.2+0.2*i/199 for i in range(1,200)]
pos_omcd=[1.1+0.14+0.2+0.2+0.1+0.2+0.2+0.2*i/199 for i in range(1,200)]
pos_imcd=[1.1+0.14+0.2+0.2+0.1+0.2+0.2+0.2+0.5*i/199 for i in range(1,200)]
pos=pos_pt+pos_s3+pos_sdl+pos_mtal+pos_ctal+pos_dct+pos_cnt+pos_ccd+pos_omcd+pos_imcd

# %%
s='Na'
male = open('male_con_of_'+s+'_in_Lumen.txt','r')
female = open('female_con_of_'+s+'_in_Lumen.txt','r')
male_list = []
female_list = []
for i in male:
    line = i.split(' ')
    #print(line)
    #pos.append(float(line[5]))
    male_list.append(float(line[0]))
    #male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
for i in female:
    line = i.split(' ')
    female_list.append(float(line[0]))
    #female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
plt.figure(figsize=[20,20])
plt.plot(pos,male_list,'-',label='Male')
plt.plot(pos,female_list,'--',label='Female')
plt.plot(pos_pt+pos_s3,[130 for i in pos_pt+pos_s3],'--',pos_sdl,[140 for i in pos_sdl],'--',pos_mtal+pos_ctal,[145 for i in pos_mtal+pos_ctal],'--',pos_dct,[55 for i in pos_dct],'--',pos_cnt,[50 for i in pos_cnt],'--',pos_ccd+pos_omcd+pos_imcd,[60 for i in pos_ccd+pos_omcd+pos_imcd],'--')
plt.text(0.5,132,'PT',fontsize=20)
plt.text(1.12,142,'SDL',fontsize=20)
plt.text(1.36,147,'TAL',fontsize=20)
plt.text(1.63,57,'DCT',fontsize=20)
plt.text(1.78,52,'CNT',fontsize=20)
plt.text(2.4,62,'CD',fontsize=20)
plt.legend(fontsize=20,markerscale=5)
plt.tick_params(labelsize=20)
plt.ylabel('Concentration of Na$^+$',fontsize=20)
plt.show()

# %%
s='H2PO4'
male = open('male_con_of_'+s+'_in_Lumen.txt','r')
female = open('female_con_of_'+s+'_in_Lumen.txt','r')
male_list = []
female_list = []
for i in male:
    line = i.split(' ')
    #print(line)
    #pos.append(float(line[5]))
    male_list.append(float(line[0]))
    #male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
for i in female:
    line = i.split(' ')
    female_list.append(float(line[0]))
    #female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
plt.figure(figsize=[20,20])
plt.plot(pos,male_list,'-',color='black',label='Male',linewidth=2)
plt.plot(pos,female_list,'--',dashes=(10,10),color='black',label='Female',linewidth=2)
pt_ht=0
sdl_ht=1
tal_ht=0
dct_ht=1
cnt_ht=5
cd_ht=10
plt.plot(pos_pt+pos_s3,[pt_ht for i in pos_pt+pos_s3],'--',pos_sdl,[sdl_ht for i in pos_sdl],'--',pos_mtal+pos_ctal,[tal_ht for i in pos_mtal+pos_ctal],'--',pos_dct,[dct_ht for i in pos_dct],'--',pos_cnt,[cnt_ht for i in pos_cnt],'--',pos_ccd+pos_omcd+pos_imcd,[cd_ht for i in pos_ccd+pos_omcd+pos_imcd],'--')
plt.text(0.5,pt_ht+0.5,'PT',fontsize=30)
plt.text(1.12,sdl_ht+0.5,'SDL',fontsize=30)
plt.text(1.36,tal_ht+0.5,'TAL',fontsize=30)
plt.text(1.63,dct_ht+0.5,'DCT',fontsize=30)
plt.text(1.78,cnt_ht+0.5,'CNT',fontsize=30)
plt.text(2.4,cd_ht+0.5,'CD',fontsize=30)
plt.legend(fontsize=30,markerscale=5)
plt.tick_params(labelsize=30)
plt.ylabel('[H2PO$_4^-$] (mM)',fontsize=40)
plt.savefig('concentration_of_H2PO4')
#plt.show()

# %%
s='H'
male = open('male_con_of_'+s+'_in_Lumen.txt','r')
female = open('female_con_of_'+s+'_in_Lumen.txt','r')
male_list = []
female_list = []
for i in male:
    line = i.split(' ')
    #print(line)
    #pos.append(float(line[5]))
    male_list.append(float(line[0]))
    male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
for i in female:
    line = i.split(' ')
    female_list.append(float(line[0]))
    female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
plt.figure(figsize=[20,20])
plt.plot(pos,male_ph,'-',label='Male')
plt.plot(pos,female_ph,'--',label='Female')
#plt.plot(pos_pt+pos_s3,[130 for i in pos_pt+pos_s3],'--',pos_sdl,[140 for i in pos_sdl],'--',pos_mtal+pos_ctal,[145 for i in pos_mtal+pos_ctal],'--',pos_dct,[55 for i in pos_dct],'--',pos_cnt,[50 for i in pos_cnt],'--',pos_ccd+pos_omcd+pos_imcd,[60 for i in pos_ccd+pos_omcd+pos_imcd],'--')
#plt.text(0.5,132,'PT',fontsize=20)
#plt.text(1.12,142,'SDL',fontsize=20)
#plt.text(1.36,147,'TAL',fontsize=20)
#plt.text(1.63,57,'DCT',fontsize=20)
#plt.text(1.78,52,'CNT',fontsize=20)
#plt.text(2.4,62,'CD',fontsize=20)
plt.legend(fontsize=20,markerscale=5)
plt.tick_params(labelsize=20)
plt.ylabel('pH',fontsize=20)
plt.show()
print(male_ph[-1],female_ph[-1])

# %%
female_osm_lumen = np.zeros(1791)
for j in solute:
    lumen = open('female_con_of_'+j+'_in_Lumen.txt','r')
    m=0
    for line in lumen:
        line = line.split(' ')
        female_osm_lumen[m] = female_osm_lumen[m]+float(line[0])
        m = m+1
male_osm_lumen = np.zeros(1791)
for j in solute:
    lumen = open('male_con_of_'+j+'_in_Lumen.txt','r')
    m=0
    for line in lumen:
        line = line.split(' ')
        male_osm_lumen[m] = male_osm_lumen[m]+float(line[0])
        m = m+1
fileoutput = open('female_osm_in_lumen.txt','w')
for data in female_osm_lumen:
    fileoutput.write(str(data)+'\n')
fileoutput.close()
fileoutput = open('male_osm_in_lumen.txt','w')
for data in male_osm_lumen:
    fileoutput.write(str(data)+'\n')
fileoutput.close()

# %%
fig,axarr = plt.subplots(3,3)
fig.set_figheight(40)
fig.set_figwidth(40)

s='Na'
male = open('male_con_of_'+s+'_in_Lumen.txt','r')
female = open('female_con_of_'+s+'_in_Lumen.txt','r')
male_list = []
female_list = []
for i in male:
    line = i.split(' ')
    #print(line)
    #pos.append(float(line[5]))
    male_list.append(float(line[0]))
    #male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
for i in female:
    line = i.split(' ')
    female_list.append(float(line[0]))
    #female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
axarr[0,0].plot(pos,male_list,'-',color='black',label='Male',linewidth=2)
axarr[0,0].plot(pos,female_list,'--',dashes=(10,10),color='black',label='Female',linewidth=2)
pt_ht=130
sdl_ht=140
tal_ht=155
dct_ht=55
cnt_ht=0
cd_ht=60
axarr[0,0].plot(pos_pt+pos_s3,[pt_ht for i in pos_pt+pos_s3],'--',pos_sdl,[sdl_ht for i in pos_sdl],'--',pos_mtal+pos_ctal,[tal_ht for i in pos_mtal+pos_ctal],'--',pos_dct,[dct_ht for i in pos_dct],'--',pos_cnt,[cnt_ht for i in pos_cnt],'--',pos_ccd+pos_omcd+pos_imcd,[cd_ht for i in pos_ccd+pos_omcd+pos_imcd],'--')
axarr[0,0].text(0.5,pt_ht+2,'PT',fontsize=30)
axarr[0,0].text(1.12,sdl_ht+2,'SDL',fontsize=30)
axarr[0,0].text(1.36,tal_ht+2,'TAL',fontsize=30)
axarr[0,0].text(1.63,dct_ht+2,'DCT',fontsize=30)
axarr[0,0].text(1.78,cnt_ht+2,'CNT',fontsize=30)
axarr[0,0].text(2.4,cd_ht+2,'CD',fontsize=30)
axarr[0,0].legend(fontsize=30,markerscale=5)
axarr[0,0].tick_params(labelsize=30)
axarr[0,0].set_ylabel('[Na$^+$] (mM)',fontsize=40)
axarr[0,0].get_xaxis().set_visible(False)

s='K'
male = open('male_con_of_'+s+'_in_Lumen.txt','r')
female = open('female_con_of_'+s+'_in_Lumen.txt','r')
male_list = []
female_list = []
for i in male:
    line = i.split(' ')
    #print(line)
    #pos.append(float(line[5]))
    male_list.append(float(line[0]))
    #male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
for i in female:
    line = i.split(' ')
    female_list.append(float(line[0]))
    #female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
axarr[0,1].plot(pos,male_list,'-',color='black',label='Male',linewidth=2)
axarr[0,1].plot(pos,female_list,'--',dashes=(10,10),color='black',label='Female',linewidth=2)
pt_ht=20
sdl_ht=25
tal_ht=20
dct_ht=0
cnt_ht=10
cd_ht=60
axarr[0,1].plot(pos_pt+pos_s3,[pt_ht for i in pos_pt+pos_s3],'--',pos_sdl,[sdl_ht for i in pos_sdl],'--',pos_mtal+pos_ctal,[tal_ht for i in pos_mtal+pos_ctal],'--',pos_dct,[dct_ht for i in pos_dct],'--',pos_cnt,[cnt_ht for i in pos_cnt],'--',pos_ccd+pos_omcd+pos_imcd,[cd_ht for i in pos_ccd+pos_omcd+pos_imcd],'--')
axarr[0,1].text(0.5,22,'PT',fontsize=30)
axarr[0,1].text(1.12,27,'SDL',fontsize=30)
axarr[0,1].text(1.36,22,'TAL',fontsize=30)
axarr[0,1].text(1.63,2,'DCT',fontsize=30)
axarr[0,1].text(1.78,12,'CNT',fontsize=30)
axarr[0,1].text(2.4,62,'CD',fontsize=30)
axarr[0,1].legend(fontsize=30,markerscale=5)
axarr[0,1].tick_params(labelsize=30)
axarr[0,1].set_ylabel('[K$^+$] (mM)',fontsize=40)
axarr[0,1].get_xaxis().set_visible(False)

s='Cl'
male = open('male_con_of_'+s+'_in_Lumen.txt','r')
female = open('female_con_of_'+s+'_in_Lumen.txt','r')
male_list = []
female_list = []
for i in male:
    line = i.split(' ')
    #print(line)
    #pos.append(float(line[5]))
    male_list.append(float(line[0]))
    #male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
for i in female:
    line = i.split(' ')
    female_list.append(float(line[0]))
    #female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
axarr[0,2].plot(pos,male_list,'-',color='black',label='Male',linewidth=2)
axarr[0,2].plot(pos,female_list,'--',dashes=(10,10),color='black',label='Female',linewidth=2)
pt_ht=100
sdl_ht=105
tal_ht=120
dct_ht=0
cnt_ht=15
cd_ht=60
axarr[0,2].plot(pos_pt+pos_s3,[pt_ht for i in pos_pt+pos_s3],'--',pos_sdl,[sdl_ht for i in pos_sdl],'--',pos_mtal+pos_ctal,[tal_ht for i in pos_mtal+pos_ctal],'--',pos_dct,[dct_ht for i in pos_dct],'--',pos_cnt,[cnt_ht for i in pos_cnt],'--',pos_ccd+pos_omcd+pos_imcd,[cd_ht for i in pos_ccd+pos_omcd+pos_imcd],'--')
axarr[0,2].text(0.5,pt_ht+2,'PT',fontsize=30)
axarr[0,2].text(1.12,sdl_ht+2,'SDL',fontsize=30)
axarr[0,2].text(1.36,tal_ht+2,'TAL',fontsize=30)
axarr[0,2].text(1.63,dct_ht+2,'DCT',fontsize=30)
axarr[0,2].text(1.78,cnt_ht+2,'CNT',fontsize=30)
axarr[0,2].text(2.4,cd_ht+2,'CD',fontsize=30)
axarr[0,2].legend(fontsize=30,markerscale=5)
axarr[0,2].tick_params(labelsize=30)
axarr[0,2].set_ylabel('[Cl$^-$] (mM)',fontsize=40)
axarr[0,2].get_xaxis().set_visible(False)

s='HCO3'
male = open('male_con_of_'+s+'_in_Lumen.txt','r')
female = open('female_con_of_'+s+'_in_Lumen.txt','r')
male_list = []
female_list = []
for i in male:
    line = i.split(' ')
    #print(line)
    #pos.append(float(line[5]))
    male_list.append(float(line[0]))
    #male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
for i in female:
    line = i.split(' ')
    female_list.append(float(line[0]))
    #female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
axarr[1,0].plot(pos,male_list,'-',color='black',label='Male',linewidth=2)
axarr[1,0].plot(pos,female_list,'--',dashes=(10,10),color='black',label='Female',linewidth=2)
pt_ht=20
sdl_ht=25
tal_ht=10
dct_ht=4
cnt_ht=2.25
cd_ht=0
axarr[1,0].plot(pos_pt+pos_s3,[pt_ht for i in pos_pt+pos_s3],'--',pos_sdl,[sdl_ht for i in pos_sdl],'--',pos_mtal+pos_ctal,[tal_ht for i in pos_mtal+pos_ctal],'--',pos_dct,[dct_ht for i in pos_dct],'--',pos_cnt,[cnt_ht for i in pos_cnt],'--',pos_ccd+pos_omcd+pos_imcd,[cd_ht for i in pos_ccd+pos_omcd+pos_imcd],'--')
axarr[1,0].text(0.5,pt_ht+0.5,'PT',fontsize=30)
axarr[1,0].text(1.12,sdl_ht+0.5,'SDL',fontsize=30)
axarr[1,0].text(1.36,tal_ht+0.5,'TAL',fontsize=30)
axarr[1,0].text(1.63,dct_ht+0.5,'DCT',fontsize=30)
axarr[1,0].text(1.78,cnt_ht+0.5,'CNT',fontsize=30)
axarr[1,0].text(2.4,cd_ht+0.5,'CD',fontsize=30)
axarr[1,0].legend(fontsize=30,markerscale=5)
axarr[1,0].tick_params(labelsize=30)
axarr[1,0].set_ylabel('[HCO$_3^-$] (mM)',fontsize=40)
axarr[1,0].get_xaxis().set_visible(False)

s='NH4'
male = open('male_con_of_'+s+'_in_Lumen.txt','r')
female = open('female_con_of_'+s+'_in_Lumen.txt','r')
male_list = []
female_list = []
for i in male:
    line = i.split(' ')
    #print(line)
    #pos.append(float(line[5]))
    male_list.append(float(line[0]))
    #male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
for i in female:
    line = i.split(' ')
    female_list.append(float(line[0]))
    #female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
axarr[1,1].plot(pos,male_list,'-',color='black',label='Male',linewidth=2)
axarr[1,1].plot(pos,female_list,'--',dashes=(10,10),color='black',label='Female',linewidth=2)
pt_ht=0
sdl_ht=5
tal_ht=0
dct_ht=5
cnt_ht=10
cd_ht=30
axarr[1,1].plot(pos_pt+pos_s3,[pt_ht for i in pos_pt+pos_s3],'--',pos_sdl,[sdl_ht for i in pos_sdl],'--',pos_mtal+pos_ctal,[tal_ht for i in pos_mtal+pos_ctal],'--',pos_dct,[dct_ht for i in pos_dct],'--',pos_cnt,[cnt_ht for i in pos_cnt],'--',pos_ccd+pos_omcd+pos_imcd,[cd_ht for i in pos_ccd+pos_omcd+pos_imcd],'--')
axarr[1,1].text(0.5,pt_ht+1,'PT',fontsize=30)
axarr[1,1].text(1.12,sdl_ht+1,'SDL',fontsize=30)
axarr[1,1].text(1.36,tal_ht+1,'TAL',fontsize=30)
axarr[1,1].text(1.63,dct_ht+1,'DCT',fontsize=30)
axarr[1,1].text(1.78,cnt_ht+1,'CNT',fontsize=30)
axarr[1,1].text(2.4,cd_ht+1,'CD',fontsize=30)
axarr[1,1].legend(fontsize=30,markerscale=5)
axarr[1,1].tick_params(labelsize=30)
axarr[1,1].set_ylabel('[NH$_4^+$] (mM)',fontsize=40)
axarr[1,1].get_xaxis().set_visible(False)

s='TA'
male = open('male_con_of_'+s+'_in_Lumen.txt','r')
female = open('female_con_of_'+s+'_in_Lumen.txt','r')
male_list = []
female_list = []
for i in male:
    line = i.split(' ')
    #print(line)
    #pos.append(float(line[5]))
    male_list.append(float(line[0]))
    #male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
for i in female:
    line = i.split(' ')
    female_list.append(float(line[0]))
    #female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
axarr[1,2].plot(pos,male_list,'-',color='black',label='Male',linewidth=2)
axarr[1,2].plot(pos,female_list,'--',dashes=(10,10),color='black',label='Female',linewidth=2)
pt_ht=0
sdl_ht=5
tal_ht=0
dct_ht=5
cnt_ht=20
cd_ht=60
axarr[1,2].plot(pos_pt+pos_s3,[pt_ht for i in pos_pt+pos_s3],'--',pos_sdl,[sdl_ht for i in pos_sdl],'--',pos_mtal+pos_ctal,[tal_ht for i in pos_mtal+pos_ctal],'--',pos_dct,[dct_ht for i in pos_dct],'--',pos_cnt,[cnt_ht for i in pos_cnt],'--',pos_ccd+pos_omcd+pos_imcd,[cd_ht for i in pos_ccd+pos_omcd+pos_imcd],'--')
axarr[1,2].text(0.5,pt_ht+2,'PT',fontsize=30)
axarr[1,2].text(1.12,sdl_ht+2,'SDL',fontsize=30)
axarr[1,2].text(1.36,tal_ht+2,'TAL',fontsize=30)
axarr[1,2].text(1.63,dct_ht+2,'DCT',fontsize=30)
axarr[1,2].text(1.78,cnt_ht+2,'CNT',fontsize=30)
axarr[1,2].text(2.4,cd_ht+2,'CD',fontsize=30)
axarr[1,2].legend(fontsize=30,markerscale=5)
axarr[1,2].tick_params(labelsize=30)
axarr[1,2].set_ylabel('[TA] (mM)',fontsize=40)
axarr[1,2].get_xaxis().set_visible(False)

s='urea'
male = open('male_con_of_'+s+'_in_Lumen.txt','r')
female = open('female_con_of_'+s+'_in_Lumen.txt','r')
male_list = []
female_list = []
for i in male:
    line = i.split(' ')
    #print(line)
    #pos.append(float(line[5]))
    male_list.append(float(line[0]))
    #male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
for i in female:
    line = i.split(' ')
    female_list.append(float(line[0]))
    #female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
axarr[2,0].plot(pos,male_list,'-',color='black',label='Male',linewidth=2)
axarr[2,0].plot(pos,female_list,'--',dashes=(10,10),color='black',label='Female',linewidth=2)
pt_ht=20
sdl_ht=40
tal_ht=55
dct_ht=30
cnt_ht=50
cd_ht=200
axarr[2,0].plot(pos_pt+pos_s3,[pt_ht for i in pos_pt+pos_s3],'--',pos_sdl,[sdl_ht for i in pos_sdl],'--',pos_mtal+pos_ctal,[tal_ht for i in pos_mtal+pos_ctal],'--',pos_dct,[dct_ht for i in pos_dct],'--',pos_cnt,[cnt_ht for i in pos_cnt],'--',pos_ccd+pos_omcd+pos_imcd,[cd_ht for i in pos_ccd+pos_omcd+pos_imcd],'--')
axarr[2,0].text(0.5,pt_ht+2,'PT',fontsize=30)
axarr[2,0].text(1.12,sdl_ht+2,'SDL',fontsize=30)
axarr[2,0].text(1.36,tal_ht+2,'TAL',fontsize=30)
axarr[2,0].text(1.63,dct_ht+2,'DCT',fontsize=30)
axarr[2,0].text(1.78,cnt_ht+2,'CNT',fontsize=30)
axarr[2,0].text(2.4,cd_ht+2,'CD',fontsize=30)
axarr[2,0].legend(fontsize=30,markerscale=5)
axarr[2,0].tick_params(labelsize=30)
axarr[2,0].set_ylabel('[urea] (mM)',fontsize=40)
axarr[2,0].get_xaxis().set_visible(False)

s='H'
male = open('male_con_of_'+s+'_in_Lumen.txt','r')
female = open('female_con_of_'+s+'_in_Lumen.txt','r')
male_list = []
female_list = []
for i in male:
    line = i.split(' ')
    #print(line)
    #pos.append(float(line[5]))
    male_list.append(float(line[0]))
    male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
for i in female:
    line = i.split(' ')
    female_list.append(float(line[0]))
    female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
axarr[2,1].plot(pos,male_ph,'-',color='black',label='Male',linewidth=2)
axarr[2,1].plot(pos,female_ph,'--',dashes=(10,10),color='black',label='Female',linewidth=2)
pt_ht=7
sdl_ht=7.2
tal_ht=7
dct_ht=6
cnt_ht=5.8
cd_ht=6.125
axarr[2,1].plot(pos_pt+pos_s3,[pt_ht for i in pos_pt+pos_s3],'--',pos_sdl,[sdl_ht for i in pos_sdl],'--',pos_mtal+pos_ctal,[tal_ht for i in pos_mtal+pos_ctal],'--',pos_dct,[dct_ht for i in pos_dct],'--',pos_cnt,[cnt_ht for i in pos_cnt],'--',pos_ccd+pos_omcd+pos_imcd,[cd_ht for i in pos_ccd+pos_omcd+pos_imcd],'--')
axarr[2,1].text(0.5,pt_ht+0.05,'PT',fontsize=30)
axarr[2,1].text(1.12,sdl_ht+0.05,'SDL',fontsize=30)
axarr[2,1].text(1.36,tal_ht+0.05,'TAL',fontsize=30)
axarr[2,1].text(1.63,dct_ht+0.05,'DCT',fontsize=30)
axarr[2,1].text(1.78,cnt_ht+0.05,'CNT',fontsize=30)
axarr[2,1].text(2.4,cd_ht+0.05,'CD',fontsize=30)
axarr[2,1].legend(fontsize=30,markerscale=5)
axarr[2,1].tick_params(labelsize=30)
axarr[2,1].set_ylabel('pH',fontsize=40)
axarr[2,1].get_xaxis().set_visible(False)
print(female_ph[-1],male_ph[-1])

male = open('male_osm_in_Lumen.txt','r')
female = open('female_osm_in_Lumen.txt','r')
male_list = []
female_list = []
for i in male:
    line = i.split(' ')
    #print(line)
    #pos.append(float(line[5]))
    male_list.append(float(line[0]))
    #male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
for i in female:
    line = i.split(' ')
    female_list.append(float(line[0]))
    #female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
axarr[2,2].plot(pos,male_list,'-',color='black',label='Male',linewidth=2)
axarr[2,2].plot(pos,female_list,'--',dashes=(10,10),color='black',label='Female',linewidth=2)
pt_ht=280
sdl_ht=620
tal_ht=650
dct_ht=50
cnt_ht=310
cd_ht=500
axarr[2,2].plot(pos_pt+pos_s3,[pt_ht for i in pos_pt+pos_s3],'--',pos_sdl,[sdl_ht for i in pos_sdl],'--',pos_mtal+pos_ctal,[tal_ht for i in pos_mtal+pos_ctal],'--',pos_dct,[dct_ht for i in pos_dct],'--',pos_cnt,[cnt_ht for i in pos_cnt],'--',pos_ccd+pos_omcd+pos_imcd,[cd_ht for i in pos_ccd+pos_omcd+pos_imcd],'--')
axarr[2,2].text(0.5,pt_ht+2,'PT',fontsize=30)
axarr[2,2].text(1.12,sdl_ht+2,'SDL',fontsize=30)
axarr[2,2].text(1.36,tal_ht+2,'TAL',fontsize=30)
axarr[2,2].text(1.63,dct_ht+2,'DCT',fontsize=30)
axarr[2,2].text(1.78,cnt_ht+2,'CNT',fontsize=30)
axarr[2,2].text(2.4,cd_ht+2,'CD',fontsize=30)
axarr[2,2].legend(fontsize=30,markerscale=5)
axarr[2,2].tick_params(labelsize=30)
axarr[2,2].set_ylabel('Osmolality (mosm/kg H$_2$O)',fontsize=40)
axarr[2,2].get_xaxis().set_visible(False)

#male = open('male_water_volume_in_Lumen.txt','r')
#female = open('female_water_volume_in_Lumen.txt','r')
#male_list = []
#female_list = []
#for i in male:
#    line = i.split(' ')
#    #print(line)
#    #pos.append(float(line[5]))
#    male_list.append(float(line[0]))
#for i in female:
#    line = i.split(' ')
#    female_list.append(float(line[0]))
#axarr[3,0].plot(pos,male_list,'-',color='black',label='Male',linewidth=2)
#axarr[3,0].plot(pos,female_list,'--',dashes=(10,10),color='black',label='Female',linewidth=2)
#pt_ht=5
#sdl_ht=4
#tal_ht=3.5
#dct_ht=2
#cnt_ht=0
#cd_ht=1
#axarr[3,0].plot(pos_pt+pos_s3,[pt_ht for i in pos_pt+pos_s3],'--',pos_sdl,[sdl_ht for i in pos_sdl],'--',pos_mtal+pos_ctal,[tal_ht for i in pos_mtal+pos_ctal],'--',pos_dct,[dct_ht for i in pos_dct],'--',pos_cnt,[cnt_ht for i in pos_cnt],'--',pos_ccd+pos_omcd+pos_imcd,[cd_ht for i in pos_ccd+pos_omcd+pos_imcd],'--')
#axarr[3,0].text(0.5,pt_ht+0.5,'PT',fontsize=30)
#axarr[3,0].text(1.12,sdl_ht+0.5,'SDL',fontsize=30)
#axarr[3,0].text(1.36,tal_ht+0.5,'TAL',fontsize=30)
#axarr[3,0].text(1.63,dct_ht+0.5,'DCT',fontsize=30)
#axarr[3,0].text(1.78,cnt_ht+0.5,'CNT',fontsize=30)
#axarr[3,0].text(2.4,cd_ht+0.5,'CD',fontsize=30)
#axarr[3,0].legend(fontsize=30,markerscale=5)
#axarr[3,0].tick_params(labelsize=30)
#axarr[3,0].set_ylabel('Volume flow (nl/min)',fontsize=40)
#axarr[3,0].get_xaxis().set_visible(False)

#male = open('male_pres_in_Lumen.txt','r')
#female = open('female_pres_in_Lumen.txt','r')
#male_list = []
#female_list = []
#for i in male:
#    line = i.split(' ')
#    #print(line)
#    #pos.append(float(line[5]))
#    male_list.append(float(line[0]))
#for i in female:
#    line = i.split(' ')
#    female_list.append(float(line[0]))
#axarr[3,1].plot(pos,male_list,'-',label='Male',linewidth=2)
#axarr[3,1].plot(pos,female_list,'--',dashes=(10,10),label='Female',linewidth=2)
#pt_ht=8
#sdl_ht=7
#tal_ht=6.5
#dct_ht=6.25
#cnt_ht=5.5
#cd_ht=4.5
#axarr[3,1].plot(pos_pt+pos_s3,[pt_ht for i in pos_pt+pos_s3],'--',pos_sdl,[sdl_ht for i in pos_sdl],'--',pos_mtal+pos_ctal,[tal_ht for i in pos_mtal+pos_ctal],'--',pos_dct,[dct_ht for i in pos_dct],'--',pos_cnt,[cnt_ht for i in pos_cnt],'--',pos_ccd+pos_omcd+pos_imcd,[cd_ht for i in pos_ccd+pos_omcd+pos_imcd],'--')
#axarr[3,1].text(0.5,pt_ht+0.1,'PT',fontsize=30)
#axarr[3,1].text(1.12,sdl_ht+0.1,'SDL',fontsize=30)
#axarr[3,1].text(1.36,tal_ht+0.1,'TAL',fontsize=30)
#axarr[3,1].text(1.63,dct_ht+0.1,'DCT',fontsize=30)
#axarr[3,1].text(1.78,cnt_ht+0.1,'CNT',fontsize=30)
#axarr[3,1].text(2.4,cd_ht+0.1,'CD',fontsize=30)
#axarr[3,1].legend(fontsize=30,markerscale=5)
#axarr[3,1].tick_params(labelsize=30)
#axarr[3,1].set_ylabel('Pressure (mmHg)',fontsize=40)
#axarr[3,1].get_xaxis().set_visible(False)


plt.subplots_adjust(hspace=0.1)

axarr[0,0].text(-0.5,axarr[0,0].get_ylim()[1],'A',size=40,weight='bold')
axarr[0,1].text(-0.5,axarr[0,1].get_ylim()[1],'B',size=40,weight='bold')
axarr[0,2].text(-0.5,axarr[0,2].get_ylim()[1],'C',size=40,weight='bold')
axarr[1,0].text(-0.5,axarr[1,0].get_ylim()[1],'D',size=40,weight='bold')
axarr[1,1].text(-0.5,axarr[1,1].get_ylim()[1],'E',size=40,weight='bold')
axarr[1,2].text(-0.5,axarr[1,2].get_ylim()[1],'F',size=40,weight='bold')
axarr[2,0].text(-0.5,axarr[2,0].get_ylim()[1],'G',size=40,weight='bold')
axarr[2,1].text(-0.5,axarr[2,1].get_ylim()[1],'H',size=40,weight='bold')
axarr[2,2].text(-0.5,axarr[2,2].get_ylim()[1],'I',size=40,weight='bold')
#axarr[3,0].text(-0.5,axarr[3,0].get_ylim()[1],'J',size=40,weight='bold')

#fig.delaxes(axarr[3,1])
#fig.delaxes(axarr[3,2])

#plt.show()
plt.savefig('con_ph_volume_pres',bbox_inches='tight')
# Out:
# 5.608725182346964 5.726995837809476

# %%
fig,ax = plt.subplots()
fig.set_figheight(20)
fig.set_figwidth(20)

male = open('male_water_volume_in_Lumen.txt','r')
female = open('female_water_volume_in_Lumen.txt','r')
male_list = []
female_list = []
for i in male:
    line = i.split(' ')
    #print(line)
    #pos.append(float(line[5]))
    male_list.append(float(line[0]))
for i in female:
    line = i.split(' ')
    female_list.append(float(line[0]))
ax.plot(pos,male_list,'-',color='black',label='Male',linewidth=2)
ax.plot(pos,female_list,'--',dashes=(10,10),color='black',label='Female',linewidth=2)
pt_ht=5
sdl_ht=4
tal_ht=3.5
dct_ht=2
cnt_ht=0
cd_ht=1
ax.plot(pos_pt+pos_s3,[pt_ht for i in pos_pt+pos_s3],'--',pos_sdl,[sdl_ht for i in pos_sdl],'--',pos_mtal+pos_ctal,[tal_ht for i in pos_mtal+pos_ctal],'--',pos_dct,[dct_ht for i in pos_dct],'--',pos_cnt,[cnt_ht for i in pos_cnt],'--',pos_ccd+pos_omcd+pos_imcd,[cd_ht for i in pos_ccd+pos_omcd+pos_imcd],'--')
ax.text(0.5,pt_ht+0.5,'PT',fontsize=30)
ax.text(1.12,sdl_ht+0.5,'SDL',fontsize=30)
ax.text(1.36,tal_ht+0.5,'TAL',fontsize=30)
ax.text(1.63,dct_ht+0.5,'DCT',fontsize=30)
ax.text(1.78,cnt_ht+0.5,'CNT',fontsize=30)
ax.text(2.4,cd_ht+0.5,'CD',fontsize=30)
ax.legend(fontsize=30,markerscale=5)
ax.tick_params(labelsize=30)
ax.set_ylabel('Volume flow (nl/min)',fontsize=40)
ax.get_xaxis().set_visible(False)

#plt.show()
plt.savefig('volume flow',bbox_inches='tight')

# %%
NPT=176
NS3=25
NSDL=200
NmTAL=200
NcTAL=200
NDCT=200
NCNT=200
NCCD=200
NOMCD=200
NIMCD=200
for s in solute:
    male = open('male_con_of_'+s+'_in_Lumen.txt','r')
    female = open('female_con_of_'+s+'_in_Lumen.txt','r')
    male_list = []
    female_list = []
    #pos = [m for m in range(1,NPT+NS3-1+NSDL-1+NmTAL-1+NcTAL-1+NDCT-1+NCNT-1+NCCD-1+NOMCD-1+NIMCD-1)]
    for i in male:
        line = i.split(' ')
        #print(line)
        #pos.append(float(line[5]))
        male_list.append(float(line[0]))
        #male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
    for i in female:
        line = i.split(' ')
        female_list.append(float(line[0]))
        #female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
    plt.figure(figsize=[80,40])
    plt.scatter(pos,male_list,c='lightcoral',marker='.',label='Male')
    plt.scatter(pos,female_list,c='skyblue',marker='.',label='Female')
    plt.legend(fontsize=80,markerscale=20)
    #plt.xticks([175,199,398,597,796,995,1194,1393,1592,1791],['PT','S3','SDL','mTAL','cTAL','DCT','CNT','CCD','OMCD','IMCD'])
    plt.tick_params(labelsize=40)
    plt.xlabel('Segement',fontsize=80)
    plt.ylabel('Concentration',fontsize=80)
    #plt.savefig(s+'_con_Lumen')
    plt.show()

# %%
NPT=176
NS3=25
NSDL=200
NmTAL=200
NcTAL=200
NDCT=200
NCNT=200
NCCD=200
NOMCD=200
NIMCD=200
for s in solute:
    male = open('male_flow_of_'+s+'_in_Lumen.txt','r')
    female = open('female_flow_of_'+s+'_in_Lumen.txt','r')
    male_list = []
    female_list = []
    pos = [m for m in range(1,NPT+NS3-1+NSDL-1+NmTAL-1+NcTAL-1+NDCT-1+NCNT-1+NCCD-1+NOMCD-1+NIMCD-1)]
    for i in male:
        line = i.split(' ')
        #print(line)
        #pos.append(float(line[5]))
        male_list.append(float(line[0]))
        #male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
    for i in female:
        line = i.split(' ')
        female_list.append(float(line[0]))
        #female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
    plt.figure(figsize=[80,40])
    plt.scatter(pos,male_list,c='lightcoral',marker='.',label='Male')
    plt.scatter(pos,female_list,c='skyblue',marker='.',label='Female')
    plt.legend(fontsize=80,markerscale=20,loc=3)
    plt.xticks([175,199,398,597,796,995,1194,1393,1592,1791],['PT','S3','SDL','mTAL','cTAL','DCT','CNT','CCD','OMCD','IMCD'])
    plt.tick_params(labelsize=40)
    plt.xlabel('Segment',fontsize=80)
    plt.ylabel('Flow of'+' '+s,fontsize=80)
    plt.savefig(s+'_flow_Lumen')

# %%
NPT=176
NS3=25
NSDL=200
NmTAL=200
NcTAL=200
NDCT=200
NCNT=200
NCCD=200
NOMCD=200
NIMCD=200
male = open('male_water_volume_in_Lumen.txt','r')
female = open('female_water_volume_in_Lumen.txt','r')
male_list = []
female_list = []
pos = [m for m in range(1,NPT+NS3-1+NSDL-1+NmTAL-1+NcTAL-1+NDCT-1+NCNT-1+NCCD-1+NOMCD-1+NIMCD-1)]
for i in male:
    line = i.split(' ')
    #print(line)
    #pos.append(float(line[5]))
    male_list.append(float(line[0]))
    #male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
for i in female:
    line = i.split(' ')
    female_list.append(float(line[0]))
    #female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
plt.figure(figsize=[80,40])
plt.scatter(pos,male_list,c='r',marker='.',label='Male')
plt.scatter(pos,female_list,c='b',marker='.',label='Female')
plt.legend(fontsize=80,markerscale=20)
plt.xticks([175,199,398,597,796,995,1194,1393,1592,1791],['PT','S3','SDL','mTAL','cTAL','DCT','CNT','CCD','OMCD','IMCD'])
plt.tick_params(labelsize=40)
plt.xlabel('Segement',fontsize=80)
plt.ylabel('Water flow',fontsize=80)
plt.savefig('water_Lumen')

# %%
for s in segment:
    for j in solute:
        male = open('male'+s+'_con_of_'+j+'_in_Lumen.txt','r')
        female = open('female'+s+'_con_of_'+j+'_in_Lumen.txt','r')
        male_list = []
        female_list = []
        if s == 'pt':
            N = 176
        elif s == 's3':
            N = 25
        else:
            N = 200
        pos = [m for m in range(1,N)]
        for i in male:
            line = i.split(' ')
            #print(line)
            #pos.append(float(line[5]))
            male_list.append(float(line[0]))
            #male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
        for i in female:
            line = i.split(' ')
            female_list.append(float(line[0]))
            #female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
        plt.figure(figsize=[25,25])
        plt.scatter(pos,male_list,c='r',marker='.',label='Male')
        plt.scatter(pos,female_list,c='b',marker='.',label='Female')
        plt.legend(fontsize=68,markerscale=5)
        plt.xlabel('Position',fontsize=68)
        plt.ylabel('Concentration of'+' '+j+' '+'along'+' '+s,fontsize=68)
        plt.xticks(fontsize=40)
        plt.yticks(fontsize=40)
        plt.savefig(s+'_'+j+'_Lumen')

# %%
for s in segment:
    for j in ['H']:
        male = open('male'+s+'_con_of_'+j+'_in_Lumen.txt','r')
        female = open('female'+s+'_con_of_'+j+'_in_Lumen.txt','r')
        male_list = []
        female_list = []
        if s == 'pt':
            N = 176
        elif s == 's3':
            N = 25
        else:
            N = 200
        pos = [m for m in range(1,N)]
        for i in male:
            line = i.split(' ')
            #print(line)
            #pos.append(float(line[5]))
            male_list.append(float(line[0]))
            male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
        for i in female:
            line = i.split(' ')
            female_list.append(float(line[0]))
            female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
        plt.figure(figsize=[10,10])
        plt.scatter(pos,male_ph,c='r',marker='.',label='Male')
        plt.scatter(pos,female_ph,c='b',marker='.',label='Female')
        plt.legend()
        plt.savefig(s+'_ph')

# %%
for s in segment:
    for j in solute:
        male = open('male'+s+'_flow_of_'+j+'_in_Lumen.txt','r')
        female = open('female'+s+'_flow_of_'+j+'_in_Lumen.txt','r')
        male_list = []
        female_list = []
        if s == 'pt':
            N = 176
        elif s == 's3':
            N = 25
        else:
            N = 200
        pos = [m for m in range(1,N)]
        for i in male:
            line = i.split(' ')
            #print(line)
            #pos.append(float(line[5]))
            male_list.append(float(line[0]))
            #male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
        for i in female:
            line = i.split(' ')
            female_list.append(float(line[0]))
            #female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
        plt.figure(figsize=[10,10])
        plt.scatter(pos,male_list,c='r',marker='.',label='Male')
        plt.scatter(pos,female_list,c='b',marker='.',label='Female')
        plt.legend()
        plt.savefig(s+'_'+j+'_flow_Lumen')

# %%
for s in segment:
    male = open('male'+s+'_water_volume_in_Lumen.txt','r')
    female = open('female'+s+'_water_volume_in_Lumen.txt','r')
    male_list = []
    female_list = []
    if s == 'pt':
        N = 176
    elif s == 's3':
        N = 25
    else:
        N = 200
    pos = [m for m in range(1,N)]
    for i in male:
        line = i.split(' ')
        #print(line)
        #pos.append(float(line[5]))
        male_list.append(float(line[0]))
        #male_ph=[-np.log(i/1000)/np.log(10) for i in male_list]
    for i in female:
        line = i.split(' ')
        female_list.append(float(line[0]))
        #female_ph=[-np.log(i/1000)/np.log(10) for i in female_list]
    plt.figure(figsize=[25,25])
    plt.scatter(pos,male_list,c='r',marker='.',label='Male')
    plt.scatter(pos,female_list,c='b',marker='.',label='Female')
    plt.legend(fontsize=68,markerscale=5)
    plt.xlabel('Position',fontsize=68)
    plt.ylabel('Water volume along'+' '+s,fontsize=68)
    plt.xticks(fontsize=40)
    plt.yticks(fontsize=40)
    plt.savefig(s+'_water_Lumen')

# %%
female_osm_lumen = np.zeros(1791)
for j in solute:
    lumen = open('female_con_of_'+j+'_in_Lumen.txt','r')
    m=0
    for line in lumen:
        line = line.split(' ')
        female_osm_lumen[m] = female_osm_lumen[m]+float(line[0])
        m = m+1
male_osm_lumen = np.zeros(1791)
for j in solute:
    lumen = open('male_con_of_'+j+'_in_Lumen.txt','r')
    m=0
    for line in lumen:
        line = line.split(' ')
        male_osm_lumen[m] = male_osm_lumen[m]+float(line[0])
        m = m+1
fileoutput = open('female_osm_in_lumen.txt','w')
for data in female_osm_lumen:
    fileoutput.write(str(data)+'\n')
fileoutput.close()
fileoutput = open('male_osm_in_lumen.txt','w')
for data in male_osm_lumen:
    fileoutput.write(str(data)+'\n')
fileoutput.close()

# %%
for s in segment:
    if s == 'pt':
        num = 175
    elif s == 's3':
        num = 24
    else:
        num = 199
    female_osm_lumen = np.zeros(num)
    female_osm_cell = np.zeros(num)
    female_osm_bath = np.zeros(num)
    pos = [l for l in range(1,num+1)]
    for j in solute:
        lumen = open('female'+s+'_con_of_'+j+'_in_Lumen.txt','r')
        cell = open('female'+s+'_con_of_'+j+'_in_Cell.txt','r')
        bath = open('female'+s+'_con_of_'+j+'_in_Bath.txt','r')
        m=0
        for line in lumen:
            line = line.split(' ')
            female_osm_lumen[m] = female_osm_lumen[m]+float(line[0])
            m = m+1
        l=0
        for line in cell:
            line = line.split(' ')
            female_osm_cell[l] = female_osm_cell[l]+float(line[0])
            l = l+1    
        n=0
        for line in bath:
            line = line.split(' ')
            female_osm_bath[n] = female_osm_bath[n]+float(line[0])
            n = n+1
    male_osm_lumen = np.zeros(num)
    male_osm_cell = np.zeros(num)
    male_osm_bath = np.zeros(num)
    pos = [l for l in range(1,num+1)]
    for j in solute:
        lumen = open('male'+s+'_con_of_'+j+'_in_Lumen.txt','r')
        cell = open('male'+s+'_con_of_'+j+'_in_Cell.txt','r')
        bath = open('male'+s+'_con_of_'+j+'_in_Bath.txt','r')
        m=0
        for line in lumen:
            line = line.split(' ')
            male_osm_lumen[m] = male_osm_lumen[m]+float(line[0])
            m = m+1
        l=0
        for line in cell:
            line = line.split(' ')
            male_osm_cell[l] = male_osm_cell[l]+float(line[0])
            l = l+1    
        n=0
        for line in bath:
            line = line.split(' ')
            male_osm_bath[n] = male_osm_bath[n]+float(line[0])
            n = n+1
    plt.figure(figsize=[25,25])
    plt.scatter(pos,female_osm_lumen,c='b',marker='.',label='Female')
    plt.scatter(pos,male_osm_lumen,c='r',marker='.',label='Male')
    #plt.scatter(pos,osm_cell,c='g',marker='.',label='Cell')
    #plt.scatter(pos,osm_bath,c='b',marker='.',label='Bath')
    plt.legend(fontsize=68,markerscale=5)
    plt.xlabel('Position',fontsize=68)
    plt.ylabel('Luminal osmolality along'+' '+s,fontsize=68)
    plt.xticks(fontsize=40)
    plt.yticks(fontsize=40)
    plt.savefig(s+'_osm')

# %%
for s in segment:
    if s == 'pt':
        num = 175
    elif s == 's3':
        num = 24
    else:
        num = 199
    female_osm_lumen = np.zeros(num)
    female_osm_cell = np.zeros(num)
    female_osm_bath = np.zeros(num)
    pos = [l for l in range(1,num+1)]
    for j in solute:
        lumen = open('female'+s+'_con_of_'+j+'_in_Lumen.txt','r')
        cell = open('female'+s+'_con_of_'+j+'_in_Cell.txt','r')
        bath = open('female'+s+'_con_of_'+j+'_in_Bath.txt','r')
        m=0
        for line in lumen:
            line = line.split(' ')
            female_osm_lumen[m] = female_osm_lumen[m]+float(line[0])
            m = m+1
        l=0
        for line in cell:
            line = line.split(' ')
            female_osm_cell[l] = female_osm_cell[l]+float(line[0])
            l = l+1    
        n=0
        for line in bath:
            line = line.split(' ')
            female_osm_bath[n] = female_osm_bath[n]+float(line[0])
            n = n+1
    male_osm_lumen = np.zeros(num)
    male_osm_cell = np.zeros(num)
    male_osm_bath = np.zeros(num)
    pos = [l for l in range(1,num+1)]
    for j in solute:
        lumen = open('male'+s+'_con_of_'+j+'_in_Lumen.txt','r')
        cell = open('male'+s+'_con_of_'+j+'_in_Cell.txt','r')
        bath = open('male'+s+'_con_of_'+j+'_in_Bath.txt','r')
        m=0
        for line in lumen:
            line = line.split(' ')
            male_osm_lumen[m] = male_osm_lumen[m]+float(line[0])
            m = m+1
        l=0
        for line in cell:
            line = line.split(' ')
            male_osm_cell[l] = male_osm_cell[l]+float(line[0])
            l = l+1    
        n=0
        for line in bath:
            line = line.split(' ')
            male_osm_bath[n] = male_osm_bath[n]+float(line[0])
            n = n+1
    plt.figure(figsize=[25,25])
    plt.scatter(pos,female_osm_bath,c='b',marker='.',label='Female')
    plt.scatter(pos,male_osm_bath,c='r',marker='.',label='Male')
    #plt.scatter(pos,osm_cell,c='g',marker='.',label='Cell')
    #plt.scatter(pos,osm_bath,c='b',marker='.',label='Bath')
    plt.legend(fontsize=68,markerscale=5)
    plt.xlabel('Cell Index',fontsize=68)
    plt.ylabel('Interstitial osmolality along'+' '+s,fontsize=68)
    plt.xticks(fontsize=40)
    plt.yticks(fontsize=40)
    plt.savefig(s+'_osm_interstitial')

# %%
Na_lumen = np.zeros(49)
Na_bath = np.zeros(49)
pos = [l for l in range(1,50)]
lumen = open('femaleimcd_con_of_Na_in_Lumen.txt','r')
bath = open('femaleimcd_con_of_Na_in_Bath.txt','r')
m=0
for line in lumen:
    line = line.split(' ')
    Na_lumen[m] = Na_lumen[m]+float(line[0])
    m = m+1
n=0
for line in bath:
    line = line.split(' ')
    Na_bath[n] = Na_bath[n]+float(line[0])
    n = n+1
plt.figure(figsize=[10,10])
plt.scatter(pos,Na_lumen,c='r',marker='.',label='Lumen')
plt.scatter(pos,Na_bath,c='b',marker='.',label='Bath')
plt.legend()
plt.savefig('imcd_Na_Lumen_Bath')

# %%
male_H2PO4_arr=np.zeros(len(new_segment))
male_HPO4_arr=np.zeros(len(new_segment))
male_H2PO4=open('male_H2PO4_transport.txt','r')
male_HPO4=open('male_HPO4_transport.txt','r')
m=0
for line in male_H2PO4:
    line = line.split(' ')
    male_H2PO4_arr[m] = float(line[0])
    m = m+1
n=0
for line in male_HPO4:
    line = line.split(' ')
    male_HPO4_arr[n] = float(line[0])
    n = n+1
male_TA_transport = (10**(7.4-6.8)*male_H2PO4_arr-male_HPO4_arr)/(1+10**(7.4-6.8))

fileoutput = open('male_TA_transport.txt','w')
for data in male_TA_transport:
    fileoutput.write(str(data)+'\n')
fileoutput.close()

female_H2PO4_arr=np.zeros(len(new_segment))
female_HPO4_arr=np.zeros(len(new_segment))
female_H2PO4=open('female_H2PO4_transport.txt','r')
female_HPO4=open('female_HPO4_transport.txt','r')
m=0
for line in female_H2PO4:
    line = line.split(' ')
    female_H2PO4_arr[m] = float(line[0])
    m = m+1
n=0
for line in female_HPO4:
    line = line.split(' ')
    female_HPO4_arr[n] = float(line[0])
    n = n+1
female_TA_transport = (10**(7.4-6.8)*female_H2PO4_arr-female_HPO4_arr)/(1+10**(7.4-6.8))

fileoutput = open('female_TA_transport.txt','w')
for data in female_TA_transport:
    fileoutput.write(str(data)+'\n')
fileoutput.close()

# %%
male_H2PO4_arr=np.zeros(len(segment))
male_HPO4_arr=np.zeros(len(segment))
male_H2PO4=open('male_H2PO4_delivery.txt','r')
male_HPO4=open('male_HPO4_delivery.txt','r')
m=0
for line in male_H2PO4:
    line = line.split(' ')
    male_H2PO4_arr[m] = float(line[0])
    m = m+1
n=0
for line in male_HPO4:
    line = line.split(' ')
    male_HPO4_arr[n] = float(line[0])
    n = n+1
male_TA_delivery = (10**(7.4-6.8)*male_H2PO4_arr-male_HPO4_arr)/(1+10**(7.4-6.8))

fileoutput = open('male_TA_delivery.txt','w')
for data in male_TA_delivery:
    fileoutput.write(str(data)+'\n')
fileoutput.close()

female_H2PO4_arr=np.zeros(len(segment))
female_HPO4_arr=np.zeros(len(segment))
female_H2PO4=open('female_H2PO4_delivery.txt','r')
female_HPO4=open('female_HPO4_delivery.txt','r')
m=0
for line in female_H2PO4:
    line = line.split(' ')
    female_H2PO4_arr[m] = float(line[0])
    m = m+1
n=0
for line in female_HPO4:
    line = line.split(' ')
    female_HPO4_arr[n] = float(line[0])
    n = n+1
female_TA_delivery = (10**(7.4-6.8)*female_H2PO4_arr-female_HPO4_arr)/(1+10**(7.4-6.8))

fileoutput = open('female_TA_delivery.txt','w')
for data in female_TA_delivery:
    fileoutput.write(str(data)+'\n')
fileoutput.close()

# %%
male_H2PO4_arr=np.zeros(1791)
male_HPO4_arr=np.zeros(1791)
male_H2PO4=open('male_con_of_H2PO4_in_Lumen.txt','r')
male_HPO4=open('male_con_of_HPO4_in_Lumen.txt','r')
m=0
for line in male_H2PO4:
    line = line.split(' ')
    male_H2PO4_arr[m] = float(line[0])
    m = m+1
n=0
for line in male_HPO4:
    line = line.split(' ')
    male_HPO4_arr[n] = float(line[0])
    n = n+1
male_TA_delivery = (10**(7.4-6.8)*male_H2PO4_arr-male_HPO4_arr)/(1+10**(7.4-6.8))

fileoutput = open('male_con_of_TA_in_Lumen.txt','w')
for data in male_TA_delivery:
    fileoutput.write(str(data)+'\n')
fileoutput.close()

female_H2PO4_arr=np.zeros(1791)
female_HPO4_arr=np.zeros(1791)
female_H2PO4=open('female_con_of_H2PO4_in_Lumen.txt','r')
female_HPO4=open('female_con_of_HPO4_in_Lumen.txt','r')
m=0
for line in female_H2PO4:
    line = line.split(' ')
    female_H2PO4_arr[m] = float(line[0])
    m = m+1
n=0
for line in female_HPO4:
    line = line.split(' ')
    female_HPO4_arr[n] = float(line[0])
    n = n+1
female_TA_delivery = (10**(7.4-6.8)*female_H2PO4_arr-female_HPO4_arr)/(1+10**(7.4-6.8))

fileoutput = open('female_con_of_TA_in_Lumen.txt','w')
for data in female_TA_delivery:
    fileoutput.write(str(data)+'\n')
fileoutput.close()

# %%
female_positive=np.zeros(199)
female_negative=np.zeros(199)
for solute in ['Na','K','NH4','H']:
    file=open('female_CNT_'+solute+'_apical_flux.txt','r')
    m=0
    for line in file:
        line=line.split(' ')
        female_positive[m]=female_positive[m]+float(line[0])
        m=m+1
for solute in ['Cl','HCO3','HPO4','H2PO4','HCO2']:
    file=open('female_CNT_'+solute+'_apical_flux.txt','r')
    m=0
    if solute == 'HPO4':
        for line in file:
            line=line.split(' ')
            female_negative[m]=female_negative[m]+2*float(line[0])
            m=m+1
    else:
        for line in file:
            line=line.split(' ')
            female_negative[m]=female_negative[m]+float(line[0])
            m=m+1
male_positive=np.zeros(199)
male_negative=np.zeros(199)
for solute in ['Na','K','NH4','H']:
    file=open('male_CNT_'+solute+'_apical_flux.txt','r')
    m=0
    for line in file:
        line=line.split(' ')
        male_positive[m]=male_positive[m]+float(line[0])
        m=m+1
for solute in ['Cl','HCO3','HPO4','H2PO4','HCO2']:
    file=open('male_CNT_'+solute+'_apical_flux.txt','r')
    m=0
    if solute == 'HPO4':
        for line in file:
            line=line.split(' ')
            male_negative[m]=male_negative[m]+2*float(line[0])
            m=m+1
    else:
        for line in file:
            line=line.split(' ')
            male_negative[m]=male_negative[m]+float(line[0])
            m=m+1
female_positive_ion_move=female_positive-female_negative
male_positive_ion_move=male_positive-female_negative
pos=[i for i in range(1,200)]
plt.plot(pos,female_positive_ion_move,label='female')
plt.plot(pos,male_positive_ion_move,label='male')
plt.legend()
plt.show

# %%
female_positive=np.zeros(199)
female_negative=np.zeros(199)
for solute in ['Na','K','NH4','H']:
    file=open('female_CNT_'+solute+'_para_flux.txt','r')
    m=0
    for line in file:
        line=line.split(' ')
        female_positive[m]=female_positive[m]+float(line[0])
        m=m+1
for solute in ['Cl','HCO3','HPO4','H2PO4','HCO2']:
    file=open('female_CNT_'+solute+'_para_flux.txt','r')
    m=0
    if solute == 'HPO4':
        for line in file:
            line=line.split(' ')
            female_negative[m]=female_negative[m]+2*float(line[0])
            m=m+1
    else:
        for line in file:
            line=line.split(' ')
            female_negative[m]=female_negative[m]+float(line[0])
            m=m+1
male_positive=np.zeros(199)
male_negative=np.zeros(199)
for solute in ['Na','K','NH4','H']:
    file=open('male_CNT_'+solute+'_para_flux.txt','r')
    m=0
    for line in file:
        line=line.split(' ')
        male_positive[m]=male_positive[m]+float(line[0])
        m=m+1
for solute in ['Cl','HCO3','HPO4','H2PO4','HCO2']:
    file=open('male_CNT_'+solute+'_para_flux.txt','r')
    m=0
    if solute == 'HPO4':
        for line in file:
            line=line.split(' ')
            male_negative[m]=male_negative[m]+2*float(line[0])
            m=m+1
    else:
        for line in file:
            line=line.split(' ')
            male_negative[m]=male_negative[m]+float(line[0])
            m=m+1
female_positive_ion_move=female_positive-female_negative
male_positive_ion_move=male_positive-female_negative
pos=[i for i in range(1,200)]
plt.plot(pos,female_positive_ion_move,label='female')
plt.plot(pos,male_positive_ion_move,label='male')
plt.legend()
plt.show

# %%
female_positive=np.zeros(199)
female_negative=np.zeros(199)
for solute in ['Na','K','NH4','H']:
    file=open('female_CNT_'+solute+'_alpha_flux.txt','r')
    m=0
    for line in file:
        line=line.split(' ')
        female_positive[m]=female_positive[m]+float(line[0])
        m=m+1
for solute in ['Cl','HCO3','HPO4','H2PO4','HCO2']:
    file=open('female_CNT_'+solute+'_alpha_flux.txt','r')
    m=0
    if solute == 'HPO4':
        for line in file:
            line=line.split(' ')
            female_negative[m]=female_negative[m]+2*float(line[0])
            m=m+1
    else:
        for line in file:
            line=line.split(' ')
            female_negative[m]=female_negative[m]+float(line[0])
            m=m+1
male_positive=np.zeros(199)
male_negative=np.zeros(199)
for solute in ['Na','K','NH4','H']:
    file=open('male_CNT_'+solute+'_alpha_flux.txt','r')
    m=0
    for line in file:
        line=line.split(' ')
        male_positive[m]=male_positive[m]+float(line[0])
        m=m+1
for solute in ['Cl','HCO3','HPO4','H2PO4','HCO2']:
    file=open('male_CNT_'+solute+'_alpha_flux.txt','r')
    m=0
    if solute == 'HPO4':
        for line in file:
            line=line.split(' ')
            male_negative[m]=male_negative[m]+2*float(line[0])
            m=m+1
    else:
        for line in file:
            line=line.split(' ')
            male_negative[m]=male_negative[m]+float(line[0])
            m=m+1
female_positive_ion_move=female_positive-female_negative
male_positive_ion_move=male_positive-female_negative
pos=[i for i in range(1,200)]
plt.plot(pos,female_positive_ion_move,label='female')
plt.plot(pos,male_positive_ion_move,label='male')
plt.legend()
plt.show

# %%
female_positive=np.zeros(199)
female_negative=np.zeros(199)
for solute in ['Na','K','NH4','H']:
    file=open('female_CNT_'+solute+'_beta_flux.txt','r')
    m=0
    for line in file:
        line=line.split(' ')
        female_positive[m]=female_positive[m]+float(line[0])
        m=m+1
for solute in ['Cl','HCO3','HPO4','H2PO4','HCO2']:
    file=open('female_CNT_'+solute+'_beta_flux.txt','r')
    m=0
    if solute == 'HPO4':
        for line in file:
            line=line.split(' ')
            female_negative[m]=female_negative[m]+2*float(line[0])
            m=m+1
    else:
        for line in file:
            line=line.split(' ')
            female_negative[m]=female_negative[m]+float(line[0])
            m=m+1
male_positive=np.zeros(199)
male_negative=np.zeros(199)
for solute in ['Na','K','NH4','H']:
    file=open('male_CNT_'+solute+'_beta_flux.txt','r')
    m=0
    for line in file:
        line=line.split(' ')
        male_positive[m]=male_positive[m]+float(line[0])
        m=m+1
for solute in ['Cl','HCO3','HPO4','H2PO4','HCO2']:
    file=open('male_CNT_'+solute+'_beta_flux.txt','r')
    m=0
    if solute == 'HPO4':
        for line in file:
            line=line.split(' ')
            male_negative[m]=male_negative[m]+2*float(line[0])
            m=m+1
    else:
        for line in file:
            line=line.split(' ')
            male_negative[m]=male_negative[m]+float(line[0])
            m=m+1
female_positive_ion_move=female_positive-female_negative
male_positive_ion_move=male_positive-female_negative
pos=[i for i in range(1,200)]
plt.plot(pos,female_positive_ion_move,label='female')
plt.plot(pos,male_positive_ion_move,label='male')
plt.legend()
plt.show

# %%
solute='K'
female_api=[]
male_api=[]
female_file=open('female_CNT_'+solute+'_apical_flux.txt','r')
male_file=open('male_CNT_'+solute+'_apical_flux.txt','r')
for i in female_file:
    line = i.split(' ')
    female_api.append(float(line[0]))
for i in male_file:
    line = i.split(' ')
    male_api.append(float(line[0]))
pos_cnt=[1.1+0.14+0.2+0.2+0.1+0.2*i/199 for i in range(1,200)]
plt.figure()
female=plt.plot(pos_cnt,female_api,label='Female')
male=plt.plot(pos_cnt,male_api,label='Male')
plt.ylabel('Apical '+solute+' flux')
plt.legend()
#plt.show()
plt.savefig('CNT_Apical_'+solute+'_flux')

female_para=[]
male_para=[]
female_file=open('female_CNT_'+solute+'_para_flux.txt','r')
male_file=open('male_CNT_'+solute+'_para_flux.txt','r')
for i in female_file:
    line = i.split(' ')
    female_para.append(float(line[0]))
for i in male_file:
    line = i.split(' ')
    male_para.append(float(line[0]))
pos_cnt=[1.1+0.14+0.2+0.2+0.1+0.2*i/199 for i in range(1,200)]
plt.figure()
female=plt.plot(pos_cnt,female_para,label='Female')
male=plt.plot(pos_cnt,male_para,label='Male')
plt.ylabel('Para '+solute+' flux')
plt.legend()
#plt.show()
plt.savefig('CNT_para_'+solute+'_flux')

female_alpha=[]
male_alpha=[]
female_file=open('female_CNT_'+solute+'_alpha_flux.txt','r')
male_file=open('male_CNT_'+solute+'_alpha_flux.txt','r')
for i in female_file:
    line = i.split(' ')
    female_alpha.append(float(line[0]))
for i in male_file:
    line = i.split(' ')
    male_alpha.append(float(line[0]))
pos_cnt=[1.1+0.14+0.2+0.2+0.1+0.2*i/199 for i in range(1,200)]
plt.figure()
female=plt.plot(pos_cnt,female_alpha,label='Female')
male=plt.plot(pos_cnt,male_alpha,label='Male')
plt.ylabel('Alpha '+solute+' flux')
plt.legend()
#plt.show()
plt.savefig('CNT_Alpha_'+solute+'_flux')

female_beta=[]
male_beta=[]
female_file=open('female_CNT_'+solute+'_beta_flux.txt','r')
male_file=open('male_CNT_'+solute+'_beta_flux.txt','r')
for i in female_file:
    line = i.split(' ')
    female_beta.append(float(line[0]))
for i in male_file:
    line = i.split(' ')
    male_beta.append(float(line[0]))
pos_cnt=[1.1+0.14+0.2+0.2+0.1+0.2*i/199 for i in range(1,200)]
plt.figure()
female=plt.plot(pos_cnt,female_beta,label='Female')
male=plt.plot(pos_cnt,male_beta,label='Male')
plt.ylabel('Beta '+solute+' flux')
plt.legend()
plt.savefig('CNT_Beta_'+solute+'_flux')

male_whole_flux=[]
female_whole_flux=[]
for i in range(len(male_api)):
    male_whole_flux.append(male_api[i]+male_para[i]+male_alpha[i]+male_beta[i])
    female_whole_flux.append(female_api[i]+female_para[i]+female_alpha[i]+female_beta[i])
plt.figure()
female=plt.plot(pos_cnt,female_whole_flux,label='Female')
male=plt.plot(pos_cnt,male_whole_flux,label='Male')
plt.ylabel('Whole '+solute+' flux leaving lumen')
plt.legend()
plt.savefig('CNT_whole_'+solute+'_flux')
#plt.show()
#print(female_api[30],male_api[30])
print(sum(female_api),sum(male_api))
print(sum(female_para),sum(male_para))
print(sum(female_alpha),sum(male_alpha))
print(sum(female_beta),sum(male_beta))

# %%
Na=[]
K=[]
NH4=[]
H=[]
Cl=[]
HCO3=[]
HPO4=[]
H2PO4=[]
HCO2=[]
Na_file=open('male_CNT_Na_para_flux.txt','r')
K_file=open('male_CNT_K_para_flux.txt','r')
NH4_file=open('male_CNT_NH4_para_flux.txt','r')
H_file=open('male_CNT_H_para_flux.txt','r')
Cl_file=open('male_CNT_Cl_para_flux.txt','r')
HCO3_file=open('male_CNT_HCO3_para_flux.txt','r')
HPO4_file=open('male_CNT_HPO4_para_flux.txt','r')
H2PO4_file=open('male_CNT_H2PO4_para_flux.txt','r')
HCO2_file=open('male_CNT_HCO2_para_flux.txt','r')
for line in Na_file:
    line=line.split(' ')
    Na.append(float(line[0]))
for line in K_file:
    line=line.split(' ')
    K.append(float(line[0]))
for line in NH4_file:
    line=line.split(' ')
    NH4.append(float(line[0]))
for line in H_file:
    line=line.split(' ')
    H.append(float(line[0]))
for line in Cl_file:
    line=line.split(' ')
    Cl.append(float(line[0]))
for line in HCO3_file:
    line=line.split(' ')
    HCO3.append(float(line[0]))
for line in HPO4_file:
    line=line.split(' ')
    HPO4.append(float(line[0]))
for line in H2PO4_file:
    line=line.split(' ')
    H2PO4.append(float(line[0]))
for line in HCO2_file:
    line=line.split(' ')
    HCO2.append(float(line[0]))
plt.figure()
index=[i for i in range(1,200)]
plt.plot(index, Na, label='Na')
plt.plot(index, K, label='K')
plt.plot(index, NH4, label='NH4')
plt.plot(index, H, label='H')
plt.plot(index, Cl, label='Cl')
plt.plot(index, HCO3, label='HCO3')
plt.plot(index, HPO4, label='HPO4')
plt.plot(index, H2PO4, label='H2PO4')
plt.plot(index, HCO2, label='HCO2')
plt.legend(loc=1)
plt.ylabel('para flux')
#plt.show()
plt.savefig('male_CNT_para_flux')

# %%
K_total=[]
K_total_file=open('female_CNT_K_total_flux.txt','r')
for line in K_total_file:
    line=line.split(' ')
    K_total.append(float(line[0]))
sum(K_total)

# %%
male_potential_gradient=[]
female_potential_gradient=[]
male=open('maleCNT_potential_gradient_Lumen_Cell.txt','r')
female=open('femaleCNT_potential_gradient_Lumen_Cell.txt','r')
for line in male:
    line=line.split(' ')
    male_potential_gradient.append(float(line[0]))
for line in female:
    line=line.split(' ')
    female_potential_gradient.append(float(line[0]))
index=[i for i in range(1,200)]
plt.plot(index,male_potential_gradient,label='Male')
plt.plot(index,female_potential_gradient,label='Female')
plt.legend()
plt.show()

# %%
s='cnt'
j='K'
male = open('male'+s+'_flow_of_'+j+'_in_Lumen.txt','r')
female = open('female'+s+'_flow_of_'+j+'_in_Lumen.txt','r')
male_list = []
female_list = []
for i in male:
    line = i.split(' ')
    male_list.append(float(line[0]))
for i in female:
    line = i.split(' ')
    female_list.append(float(line[0]))
plt.figure()
pos_cnt=[1.1+0.14+0.2+0.2+0.1+0.2*i/199 for i in range(1,200)]
plt.scatter(pos_cnt,male_list,c='r',marker='.',label='Male')
plt.scatter(pos_cnt,female_list,c='b',marker='.',label='Female')
plt.legend()
plt.ylabel('K flow along CNT')
plt.savefig(s+'_'+j+'_flow_Lumen')
