# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# %%
Na_excretion_variations=[1.61,-2.69,0.78,0.27,4.57,8.33,
                         -8.52,5.91,3.5,6.99,18.01,
                         7.74,43.55,25.54,-49.19,4.03,-13.76]

# %%
paras=['P$_f$ in IMCD','P$_k$ in IMCD','P$_f$ in OMCD','P$_f$ in CCD','ENaC in CCD','NKA in CCD',
       'P$_f$ in CNT','ENaC in CNT','NKA in CNT','P$_f$ in DCT','NKA in DCT','NCC in DCT',
       'NKA in TAL','NKCC2 in TAL','PT length','P$_f$ in PCT/S3','NHE3 in PCT/S3']

# %%
bar_width=0.8
fig,ax=plt.subplots()
fig.set_figheight(9)
fig.set_figwidth(10)
Na=ax.barh(np.arange(len(paras)),Na_excretion_variations,bar_width,align='center'
           ,alpha=0.8,linewidth=2,edgecolor='black',color='black')
ax.set_yticks(np.arange(len(paras)))
ax.set_yticklabels(paras,fontsize=20)
plt.xticks(fontsize=20)
ax.set_xlabel('% change of Na excretion',fontsize=20)
# Out:
# Text(0.5,0,'% change of Na excretion')

# %%
bar_width=0.8
fig,axarr=plt.subplots(3,2)
fig.set_figheight(40)
fig.set_figwidth(30)
paras=['P$_f$ in IMCD','P$_k$ in IMCD','P$_f$ in OMCD','P$_f$ in CCD','ENaC in CCD','NKA in CCD',
       'P$_f$ in CNT','ENaC in CNT','NKA in CNT','P$_f$ in DCT','NKA in DCT','NCC in DCT',
       'NKA in TAL','NKCC2 in TAL','P$_f$ in PCT/S3','NHE3 in PCT/S3']

Na_excretion_variations=[1.61,-2.69,0.78,0.27,4.57,8.33,
                         -8.52,5.91,3.5,6.99,18.01,
                         7.74,43.55,25.54,4.03,-13.76]
axarr[0,0].barh(np.arange(len(paras)),Na_excretion_variations,bar_width,align='center'
           ,alpha=0.8,linewidth=2,edgecolor='black',color='black')
axarr[0,0].set_yticks(np.arange(len(paras)))
axarr[0,0].set_yticklabels(paras,fontsize=30)
axarr[0,0].tick_params(axis='both',labelsize=30)
axarr[0,0].set_xlabel('% change of Na$^+$ excretion',fontsize=30)
axarr[0,0].set_xlim(-15,50)

K_excretion_variations=[0.23,9.1,-0.68,0.45,-3.18,-5.46,
                         17.27,-2.73,-3.18,0.91,17.5,
                         9.96,43.64,25.91,3.64,-12.27]
axarr[0,1].barh(np.arange(len(paras)),K_excretion_variations,bar_width,align='center'
           ,alpha=0.8,linewidth=2,edgecolor='black',color='black')
axarr[0,1].set_yticks(np.arange(len(paras)))
axarr[0,1].set_yticklabels(paras,fontsize=30)
axarr[0,1].tick_params(axis='both',labelsize=30)
axarr[0,1].set_xlabel('% change of K$^+$ excretion',fontsize=30)
axarr[0,1].set_xlim(-15,50)

#Cl_excretion_variations=[3.48,6.1,0,4.09,7.83,13.04,
#                         15.65,9.57,6.957,16.52,71.04,
#                         44.35,203.5,129.6,17.39,-29.83]
#axarr[1,0].barh(np.arange(len(paras)),Cl_excretion_variations,bar_width,align='center'
#           ,alpha=0.8,linewidth=2,edgecolor='black',color='black')
#axarr[1,0].set_yticks(np.arange(len(paras)))
#axarr[1,0].set_yticklabels(paras,fontsize=20)
#axarr[1,0].tick_params(axis='both',labelsize=20)
#axarr[1,0].set_xlabel('% change of Cl$^-$ excretion',fontsize=20)

pH_excretion_variations=[-0.56,0,0,5.56,5.56,6.48,
                         5.37,6.48,5.56,7.41,8.7,
                         6.3,7.41,7.41,6.3,2.96]
axarr[1,0].barh(np.arange(len(paras)),pH_excretion_variations,bar_width,align='center'
           ,alpha=0.8,linewidth=2,edgecolor='black',color='black')
axarr[1,0].set_yticks(np.arange(len(paras)))
axarr[1,0].set_yticklabels(paras,fontsize=30)
axarr[1,0].tick_params(axis='both',labelsize=30)
axarr[1,0].set_xlabel('% change of pH',fontsize=30)
axarr[1,0].set_xlim(-15,50)

water_excretion_variations=[4.48,-1.119,-2.985,0,0.75,4.478,
                         4.48,1.49,0.746,4.48,15.67,
                         7.836,38.06,26.87,4.48,-14.18]
axarr[1,1].barh(np.arange(len(paras)),water_excretion_variations,bar_width,align='center'
                ,alpha=0.8,linewidth=2,edgecolor='black',color='black')
axarr[1,1].set_yticks(np.arange(len(paras)))
axarr[1,1].set_yticklabels(paras,fontsize=30)
axarr[1,1].tick_params(axis='both',labelsize=30)
axarr[1,1].set_xlabel('% change of Volume excretion',fontsize=30)
axarr[1,1].set_xlim(-15,50)

variations_length=[-55.11,-52.27,-15.74,-55.22]
x_ticks=['Na$^+$\nexcretion','K$^+$\nexcretion','pH','Volume\nexcretion']
axarr[2,0].bar(np.arange(len(x_ticks)),variations_length,0.25,align='center'
           ,alpha=0.8,linewidth=2,edgecolor='black',color='black')
axarr[2,0].set_xticks(np.arange(len(x_ticks)))
axarr[2,0].set_xticklabels(x_ticks,fontsize=30)
axarr[2,0].tick_params(axis='both',labelsize=30)
axarr[2,0].set_ylabel('% change',fontsize=30)
axarr[2,0].set_xlabel('Sensitivity analysis of length',fontsize=30)

variations_SNGFR=[879.3,332.73,14.44,497]
x_ticks=['Na$^+$\nexcretion','K$^+$\nexcretion','pH','Volume\nexcretion']
axarr[2,1].bar(np.arange(len(x_ticks)),variations_SNGFR,0.25,align='center'
           ,alpha=0.8,linewidth=2,edgecolor='black',color='black')
axarr[2,1].set_xticks(np.arange(len(x_ticks)))
axarr[2,1].set_xticklabels(x_ticks,fontsize=30)
axarr[2,1].tick_params(axis='both',labelsize=30)
axarr[2,1].set_ylabel('% change',fontsize=30)
axarr[2,1].set_xlabel('Sensitivity analysis of SNGFR',fontsize=30)

axarr[0,0].text(-24,axarr[0,0].get_ylim()[1],'A',size=40,weight='bold')
axarr[0,1].text(-24,axarr[0,1].get_ylim()[1],'B',size=40,weight='bold')
axarr[1,0].text(-24,axarr[1,0].get_ylim()[1],'C',size=40,weight='bold')
axarr[1,1].text(-24,axarr[1,1].get_ylim()[1],'D',size=40,weight='bold')
axarr[2,0].text(-0.8,axarr[2,0].get_ylim()[1],'E',size=40,weight='bold')
axarr[2,1].text(-0.8,axarr[2,1].get_ylim()[1],'F',size=40,weight='bold')

plt.subplots_adjust(wspace=0.35)
plt.savefig('sensitivity_analysis',bbox_inches='tight')
#plt.show()
